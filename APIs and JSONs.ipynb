# %%
import requests
import pandas as pd
import seaborn as sb

# %%
url = 'https://api.nal.usda.gov/fdc/v1/foods/list?query=&pageNumber=51&pageSize=194&api_key=u983gbYksVQ78GYn6mlvsMTLw0jcU0btxntKZSX0'

# %%
response=requests.get(url)
response=response.json()
response
# Out:
# [{'fdcId': 2344119,
#   'description': 'Pizza with pepperoni, from frozen, thin crust',
#   'dataType': 'Survey (FNDDS)',
#   'publicationDate': '2022-10-28',
#   'foodCode': '58106512',
#   'foodNutrients': [{'number': '203',
#     'name': 'Protein',
#     'amount': 12.2,
#     'unitName': 'G'},
#    {'number': '204',
#     'name': 'Total lipid (fat)',
#     'amount': 12.7,
#     'unitName': 'G'},
#    {'number': '205',
#     'name': 'Carbohydrate, by difference',
#     'amount': 27.5,
#     'unitName': 'G'},
#    {'number': '208', 'name': 'Energy', 'amount': 274, 'unitName': 'KCAL'},
#    {'number': '221', 'name': 'Alcohol, ethyl', 'amount': 0.0, 'unitName': 'G'},
#    {'number': '255', 'name': 'Water', 'amount': 45.2, 'unitName': 'G'},
#    {'number': '262', 'name': 'Caffeine', 'amount': 0.0, 'unitName': 'MG'},
#    {'number': '263', 'name': 'Theobromine', 'amount': 0.0, 'unitName': 'MG'},
#    {'number': '269',
#     'name': 'Sugars, total including NLEA',
#     'amount': 3.54,
#     'unitName': 'G'},
#    {'number': '291',
#     'name': 'Fiber, total dietary',
#     'amount': 2.9,
#     'unitName': 'G'},
#    {'number': '301', 'name': 'Calcium, Ca', 'amount': 218, 'unitName': 'MG'},
#    {'number': '303', 'name': 'Iron, Fe', 'amount': 2.1, 'unitName': 'MG'},
#    {'number': '304',
#     'name': 'Magnesium, Mg',
#     'amount': 24.0,
#     'unitName': 'MG'},
#    {'number': '305', 'name': 'Phosphorus, P', 'amount': 212, 'unitName': 'MG'},
#    {'number': '306', 'name': 'Potassium, K', 'amount': 204, 'unitName': 'MG'},
#    {'number': '307', 'name': 'Sodium, Na', 'amount': 523, 'unitName': 'MG'},
#    {'number': '309', 'name': 'Zinc, Zn', 'amount': 1.53, 'unitName': 'MG'},
#    {'number': '312', 'name': 'Copper, Cu', 'amount': 0.091, 'unitName': 'MG'},
#    {'number': '317', 'name': 'Selenium, Se', 'amount': 21.8, 'unitName': 'UG'},
#    {'number': '319', 'name': 'Retinol', 'amount': 61.0, 'unitName': 'UG'},
#    {'number': '320',
#     'name': 'Vitamin A, RAE',
#     'amount': 69.0,
#     'unitName': 'UG'},
#    {'number': '321',
#     'name': 'Carotene, beta',
#     'amount': 92.0,
#     'unitName': 'UG'},
#    {'number': '322',
#     'name': 'Carotene, alpha',
#     'amount': 0.0,
#     'unitName': 'UG'},
#    {'number': '323',
#     'name': 'Vitamin E (alpha-tocopherol)',
#     'amount': 0.75,
#     'unitName': 'MG'},
#    {'number': '328',
#     'name': 'Vitamin D (D2 + D3)',
#     'amount': 0.1,
#     'unitName': 'UG'},
#    {'number': '334',
#     'name': 'Cryptoxanthin, beta',
#     'amount': 0.0,
#     'unitName': 'UG'},
#    {'number': '337', 'name': 'Lycopene', 'amount': 1920.0, 'unitName': 'UG'},
#    {'number': '338',
#     'name': 'Lutein + zeaxanthin',
#     'amount': 29.0,
#     'unitName': 'UG'},
#    {'number': '401',
#     'name': 'Vitamin C, total ascorbic acid',
#     'amount': 0.1,
#     'unitName': 'MG'},
#    {'number': '404', 'name': 'Thiamin', 'amount': 0.11, 'unitName': 'MG'},
#    {'number': '405', 'name': 'Riboflavin', 'amount': 0.133, 'unitName': 'MG'},
#    {'number': '406', 'name': 'Niacin', 'amount': 1.46, 'unitName': 'MG'},
#    {'number': '415', 'name': 'Vitamin B-6', 'amount': 0.14, 'unitName': 'MG'},
#    {'number': '417',
#     'name': 'Folate, total',
#     'amount': 83.0,
#     'unitName': 'UG'},
#    {'number': '418', 'name': 'Vitamin B-12', 'amount': 0.65, 'unitName': 'UG'},
#    {'number': '421',
#     'name': 'Choline, total',
#     'amount': 20.3,
#     'unitName': 'MG'},
#    {'number': '430',
#     'name': 'Vitamin K (phylloquinone)',
#     'amount': 4.3,
#     'unitName': 'UG'},
#    {'number': '431', 'name': 'Folic acid', 'amount': 49.0, 'unitName': 'UG'},
#    {'number': '432', 'name': 'Folate, food', 'amount': 35.0, 'unitName': 'UG'},
#    {'number': '435', 'name': 'Folate, DFE', 'amount': 117, 'unitName': 'UG'},
#    {'number': '573',
#     'name': 'Vitamin E, added',
#     'amount': 0.0,
#     'unitName': 'MG'},
#    {'number': '578',
#     'name': 'Vitamin B-12, added',
#     'amount': 0.0,
#     'unitName': 'UG'},
#    {'number': '601', 'name': 'Cholesterol', 'amount': 25.0, 'unitName': 'MG'},
#    {'number': '606',
#     'name': 'Fatty acids, total saturated',
#     'amount': 6.26,
#     'unitName': 'G'},
#    {'number': '607', 'name': 'SFA 4:0', 'amount': 0.152, 'unitName': 'G'},
#    {'number': '608', 'name': 'SFA 6:0', 'amount': 0.119, 'unitName': 'G'},
#    {'number': '609', 'name': 'SFA 8:0', 'amount': 0.072, 'unitName': 'G'},
#    {'number': '610', 'name': 'SFA 10:0', 'amount': 0.176, 'unitName': 'G'},
#    {'number': '611', 'name': 'SFA 12:0', 'amount': 0.197, 'unitName': 'G'},
#    {'number': '612', 'name': 'SFA 14:0', 'amount': 0.728, 'unitName': 'G'},
#    {'number': '613', 'name': 'SFA 16:0', 'amount': 3.43, 'unitName': 'G'},
#    {'number': '614', 'name': 'SFA 18:0', 'amount': 1.2, 'unitName': 'G'},
#    {'number': '617', 'name': 'MUFA 18:1', 'amount': 3.54, 'unitName': 'G'},
#    {'number': '618', 'name': 'PUFA 18:2', 'amount': 1.66, 'unitName': 'G'},
#    {'number': '619', 'name': 'PUFA 18:3', 'amount': 0.113, 'unitName': 'G'},
#    {'number': '620', 'name': 'PUFA 20:4', 'amount': 0.015, 'unitName': 'G'},
#    {'number': '621',
#     'name': 'PUFA 22:6 n-3 (DHA)',
#     'amount': 0.0,
#     'unitName': 'G'},
#    {'number': '626', 'name': 'MUFA 16:1', 'amount': 0.2, 'unitName': 'G'},
#    {'number': '627', 'name': 'PUFA 18:4', 'amount': 0.002, 'unitName': 'G'},
#    {'number': '628', 'name': 'MUFA 20:1', 'amount': 0.032, 'unitName': 'G'},
#    {'number': '629',
#     'name': 'PUFA 20:5 n-3 (EPA)',
#     'amount': 0.003,
#     'unitName': 'G'},
#    {'number': '630', 'name': 'MUFA 22:1', 'amount': 0.002, 'unitName': 'G'},
#    {'number': '631',
#     'name': 'PUFA 22:5 n-3 (DPA)',
#     'amount': 0.007,
#     'unitName': 'G'},
#    {'number': '645',
#     'name': 'Fatty acids, total monounsaturated',
#     'amount': 3.85,
#     'unitName': 'G'},
#    {'number': '646',
#     'name': 'Fatty acids, total polyunsaturated',
#     'amount': 1.82,
#     'unitName': 'G'}]},
#  {'fdcId': 2344124,
#   'description': 'Pizza with pepperoni, from restaurant or fast food,  medium crust',
#   'dataType': 'Survey (FNDDS)',
#   'publicationDate': '2022-10-28',
#   'foodCode': '58106555',
#   'foodNutrients': [{'number': '203',
#     'name': 'Protein',
#     'amount': 11.7,
#     'unitName': 'G'},
#    {'number': '204',
#     'name': 'Total lipid (fat)',
#     'amount': 11.9,
#     'unitName': 'G'},
#    {'number': '205',
#     'name': 'Carbohydrate, by difference',
#     'amount': 32.0,
#     'unitName': 'G'},
#    {'number': '208', 'name': 'Energy', 'amount': 282, 'unitName': 'KCAL'},
#    {'number': '221', 'name': 'Alcohol, ethyl', 'amount': 0.0, 'unitName': 'G'},
#    {'number': '255', 'name': 'Water', 'amount': 41.8, 'unitName': 'G'},
#    {'number': '262', 'name': 'Caffeine', 'amount': 0.0, 'unitName': 'MG'},
#    {'number': '263', 'name': 'Theobromine', 'amount': 0.0, 'unitName': 'MG'},
#    {'number': '269',
#     'name': 'Sugars, total including NLEA',
#     'amount': 3.26,
#     'unitName': 'G'},
#    {'number': '291',
#     'name': 'Fiber, total dietary',
#     'amount': 2.3,
#     'unitName': 'G'},
#    {'number': '301', 'name': 'Calcium, Ca', 'amount': 153, 'unitName': 'MG'},
#    {'number': '303', 'name': 'Iron, Fe', 'amount': 2.52, 'unitName': 'MG'},
#    {'number': '304',
#     'name': 'Magnesium, Mg',
#     'amount': 24.0,
#     'unitName': 'MG'},
#    {'number': '305', 'name': 'Phosphorus, P', 'amount': 198, 'unitName': 'MG'},
#    {'number': '306', 'name': 'Potassium, K', 'amount': 195, 'unitName': 'MG'},
#    {'number': '307', 'name': 'Sodium, Na', 'amount': 685, 'unitName': 'MG'},
#    {'number': '309', 'name': 'Zinc, Zn', 'amount': 1.4, 'unitName': 'MG'},
#    {'number': '312', 'name': 'Copper, Cu', 'amount': 0.113, 'unitName': 'MG'},
#    {'number': '317', 'name': 'Selenium, Se', 'amount': 23.6, 'unitName': 'UG'},
#    {'number': '319', 'name': 'Retinol', 'amount': 62.0, 'unitName': 'UG'},
#    {'number': '320',
#     'name': 'Vitamin A, RAE',
#     'amount': 70.0,
#     'unitName': 'UG'},
#    {'number': '321',
#     'name': 'Carotene, beta',
#     'amount': 94.0,
#     'unitName': 'UG'},
#    {'number': '322',
#     'name': 'Carotene, alpha',
#     'amount': 0.0,
#     'unitName': 'UG'},
#    {'number': '323',
#     'name': 'Vitamin E (alpha-tocopherol)',
#     'amount': 0.87,
#     'unitName': 'MG'},
#    {'number': '328',
#     'name': 'Vitamin D (D2 + D3)',
#     'amount': 0.0,
#     'unitName': 'UG'},
#    {'number': '334',
#     'name': 'Cryptoxanthin, beta',
#     'amount': 0.0,
#     'unitName': 'UG'},
#    {'number': '337', 'name': 'Lycopene', 'amount': 1960.0, 'unitName': 'UG'},
#    {'number': '338',
#     'name': 'Lutein + zeaxanthin',
#     'amount': 24.0,
#     'unitName': 'UG'},
#    {'number': '401',
#     'name': 'Vitamin C, total ascorbic acid',
#     'amount': 0.9,
#     'unitName': 'MG'},
#    {'number': '404', 'name': 'Thiamin', 'amount': 0.43, 'unitName': 'MG'},
#    {'number': '405', 'name': 'Riboflavin', 'amount': 0.22, 'unitName': 'MG'},
#    {'number': '406', 'name': 'Niacin', 'amount': 4.14, 'unitName': 'MG'},
#    {'number': '415', 'name': 'Vitamin B-6', 'amount': 0.08, 'unitName': 'MG'},
#    {'number': '417',
#     'name': 'Folate, total',
#     'amount': 92.0,
#     'unitName': 'UG'},
#    {'number': '418', 'name': 'Vitamin B-12', 'amount': 0.5, 'unitName': 'UG'},
#    {'number': '421',
#     'name': 'Choline, total',
#     'amount': 25.4,
#     'unitName': 'MG'},
#    {'number': '430',
#     'name': 'Vitamin K (phylloquinone)',
#     'amount': 6.4,
#     'unitName': 'UG'},
#    {'number': '431', 'name': 'Folic acid', 'amount': 56.0, 'unitName': 'UG'},
#    {'number': '432', 'name': 'Folate, food', 'amount': 36.0, 'unitName': 'UG'},
#    {'number': '435', 'name': 'Folate, DFE', 'amount': 131, 'unitName': 'UG'},
#    {'number': '573',
#     'name': 'Vitamin E, added',
#     'amount': 0.0,
#     'unitName': 'MG'},
#    {'number': '578',
#     'name': 'Vitamin B-12, added',
#     'amount': 0.0,
#     'unitName': 'UG'},
#    {'number': '601', 'name': 'Cholesterol', 'amount': 25.0, 'unitName': 'MG'},
#    {'number': '606',
#     'name': 'Fatty acids, total saturated',
#     'amount': 5.09,
#     'unitName': 'G'},
#    {'number': '607', 'name': 'SFA 4:0', 'amount': 0.086, 'unitName': 'G'},
#    {'number': '608', 'name': 'SFA 6:0', 'amount': 0.068, 'unitName': 'G'},
#    {'number': '609', 'name': 'SFA 8:0', 'amount': 0.047, 'unitName': 'G'},
#    {'number': '610', 'name': 'SFA 10:0', 'amount': 0.118, 'unitName': 'G'},
#    {'number': '611', 'name': 'SFA 12:0', 'amount': 0.144, 'unitName': 'G'},
#    {'number': '612', 'name': 'SFA 14:0', 'amount': 0.545, 'unitName': 'G'},
#    {'number': '613', 'name': 'SFA 16:0', 'amount': 2.75, 'unitName': 'G'},
#    {'number': '614', 'name': 'SFA 18:0', 'amount': 1.17, 'unitName': 'G'},
#    {'number': '617', 'name': 'MUFA 18:1', 'amount': 3.51, 'unitName': 'G'},
#    {'number': '618', 'name': 'PUFA 18:2', 'amount': 1.8, 'unitName': 'G'},
#    {'number': '619', 'name': 'PUFA 18:3', 'amount': 0.188, 'unitName': 'G'},
#    {'number': '620', 'name': 'PUFA 20:4', 'amount': 0.022, 'unitName': 'G'},
#    {'number': '621',
#     'name': 'PUFA 22:6 n-3 (DHA)',
#     'amount': 0.001,
#     'unitName': 'G'},
#    {'number': '626', 'name': 'MUFA 16:1', 'amount': 0.186, 'unitName': 'G'},
#    {'number': '627', 'name': 'PUFA 18:4', 'amount': 0.001, 'unitName': 'G'},
#    {'number': '628', 'name': 'MUFA 20:1', 'amount': 0.063, 'unitName': 'G'},
#    {'number': '629',
#     'name': 'PUFA 20:5 n-3 (EPA)',
#     'amount': 0.004,
#     'unitName': 'G'},
#    {'number': '630', 'name': 'MUFA 22:1', 'amount': 0.014, 'unitName': 'G'},
#    {'number': '631',
#     'name': 'PUFA 22:5 n-3 (DPA)',
#     'amount': 0.006,
#     'unitName': 'G'},
#    {'number': '645',
#     'name': 'Fatty acids, total monounsaturated',
#     'amount': 3.85,
#     'unitName': 'G'},
#    {'number': '646',
#     'name': 'Fatty acids, total polyunsaturated',
#     'amount': 2.06,
#     'unitName': 'G'}]},
#  {'fdcId': 2344122,
#   'description': 'Pizza with pepperoni, from restaurant or fast food, NS as to type of crust',
#   'dataType': 'Survey (FNDDS)',
#   'publicationDate': '2022-10-28',
#   'foodCode': '58106540',
#   'foodNutrients': [{'number': '203',
#     'name': 'Protein',
#     'amount': 11.7,
#     'unitName': 'G'},
#    {'number': '204',
#     'name': 'Total lipid (fat)',
#     'amount': 11.9,
#     'unitName': 'G'},
#    {'number': '205',
#     'name': 'Carbohydrate, by difference',
#     'amount': 32.0,
#     'unitName': 'G'},
#    {'number': '208', 'name': 'Energy', 'amount': 282, 'unitName': 'KCAL'},
#    {'number': '221', 'name': 'Alcohol, ethyl', 'amount': 0.0, 'unitName': 'G'},
#    {'number': '255', 'name': 'Water', 'amount': 41.8, 'unitName': 'G'},
#    {'number': '262', 'name': 'Caffeine', 'amount': 0.0, 'unitName': 'MG'},
#    {'number': '263', 'name': 'Theobromine', 'amount': 0.0, 'unitName': 'MG'},
#    {'number': '269',
#     'name': 'Sugars, total including NLEA',
#     'amount': 3.26,
#     'unitName': 'G'},
#    {'number': '291',
#     'name': 'Fiber, total dietary',
#     'amount': 2.3,
#     'unitName': 'G'},
#    {'number': '301', 'name': 'Calcium, Ca', 'amount': 153, 'unitName': 'MG'},
#    {'number': '303', 'name': 'Iron, Fe', 'amount': 2.52, 'unitName': 'MG'},
#    {'number': '304',
#     'name': 'Magnesium, Mg',
#     'amount': 24.0,
#     'unitName': 'MG'},
#    {'number': '305', 'name': 'Phosphorus, P', 'amount': 198, 'unitName': 'MG'},
#    {'number': '306', 'name': 'Potassium, K', 'amount': 195, 'unitName': 'MG'},
#    {'number': '307', 'name': 'Sodium, Na', 'amount': 685, 'unitName': 'MG'},
#    {'number': '309', 'name': 'Zinc, Zn', 'amount': 1.4, 'unitName': 'MG'},
#    {'number': '312', 'name': 'Copper, Cu', 'amount': 0.113, 'unitName': 'MG'},
#    {'number': '317', 'name': 'Selenium, Se', 'amount': 23.6, 'unitName': 'UG'},
#    {'number': '319', 'name': 'Retinol', 'amount': 62.0, 'unitName': 'UG'},
#    {'number': '320',
#     'name': 'Vitamin A, RAE',
#     'amount': 70.0,
#     'unitName': 'UG'},
#    {'number': '321',
#     'name': 'Carotene, beta',
#     'amount': 94.0,
#     'unitName': 'UG'},
#    {'number': '322',
#     'name': 'Carotene, alpha',
#     'amount': 0.0,
#     'unitName': 'UG'},
#    {'number': '323',
#     'name': 'Vitamin E (alpha-tocopherol)',
#     'amount': 0.87,
#     'unitName': 'MG'},
#    {'number': '328',
#     'name': 'Vitamin D (D2 + D3)',
#     'amount': 0.0,
#     'unitName': 'UG'},
#    {'number': '334',
#     'name': 'Cryptoxanthin, beta',
#     'amount': 0.0,
#     'unitName': 'UG'},
#    {'number': '337', 'name': 'Lycopene', 'amount': 1960.0, 'unitName': 'UG'},
#    {'number': '338',
#     'name': 'Lutein + zeaxanthin',
#     'amount': 24.0,
#     'unitName': 'UG'},
#    {'number': '401',
#     'name': 'Vitamin C, total ascorbic acid',
#     'amount': 0.9,
#     'unitName': 'MG'},
#    {'number': '404', 'name': 'Thiamin', 'amount': 0.43, 'unitName': 'MG'},
#    {'number': '405', 'name': 'Riboflavin', 'amount': 0.22, 'unitName': 'MG'},
#    {'number': '406', 'name': 'Niacin', 'amount': 4.14, 'unitName': 'MG'},
#    {'number': '415', 'name': 'Vitamin B-6', 'amount': 0.08, 'unitName': 'MG'},
#    {'number': '417',
#     'name': 'Folate, total',
#     'amount': 92.0,
#     'unitName': 'UG'},
#    {'number': '418', 'name': 'Vitamin B-12', 'amount': 0.5, 'unitName': 'UG'},
#    {'number': '421',
#     'name': 'Choline, total',
#     'amount': 25.4,
#     'unitName': 'MG'},
#    {'number': '430',
#     'name': 'Vitamin K (phylloquinone)',
#     'amount': 6.4,
#     'unitName': 'UG'},
#    {'number': '431', 'name': 'Folic acid', 'amount': 56.0, 'unitName': 'UG'},
#    {'number': '432', 'name': 'Folate, food', 'amount': 36.0, 'unitName': 'UG'},
#    {'number': '435', 'name': 'Folate, DFE', 'amount': 131, 'unitName': 'UG'},
#    {'number': '573',
#     'name': 'Vitamin E, added',
#     'amount': 0.0,
#     'unitName': 'MG'},
#    {'number': '578',
#     'name': 'Vitamin B-12, added',
#     'amount': 0.0,
#     'unitName': 'UG'},
#    {'number': '601', 'name': 'Cholesterol', 'amount': 25.0, 'unitName': 'MG'},
#    {'number': '606',
#     'name': 'Fatty acids, total saturated',
#     'amount': 5.09,
#     'unitName': 'G'},
#    {'number': '607', 'name': 'SFA 4:0', 'amount': 0.086, 'unitName': 'G'},
#    {'number': '608', 'name': 'SFA 6:0', 'amount': 0.068, 'unitName': 'G'},
#    {'number': '609', 'name': 'SFA 8:0', 'amount': 0.047, 'unitName': 'G'},
#    {'number': '610', 'name': 'SFA 10:0', 'amount': 0.118, 'unitName': 'G'},
#    {'number': '611', 'name': 'SFA 12:0', 'amount': 0.144, 'unitName': 'G'},
#    {'number': '612', 'name': 'SFA 14:0', 'amount': 0.545, 'unitName': 'G'},
#    {'number': '613', 'name': 'SFA 16:0', 'amount': 2.75, 'unitName': 'G'},
#    {'number': '614', 'name': 'SFA 18:0', 'amount': 1.17, 'unitName': 'G'},
#    {'number': '617', 'name': 'MUFA 18:1', 'amount': 3.51, 'unitName': 'G'},
#    {'number': '618', 'name': 'PUFA 18:2', 'amount': 1.8, 'unitName': 'G'},
#    {'number': '619', 'name': 'PUFA 18:3', 'amount': 0.188, 'unitName': 'G'},
#    {'number': '620', 'name': 'PUFA 20:4', 'amount': 0.022, 'unitName': 'G'},
#    {'number': '621',
#     'name': 'PUFA 22:6 n-3 (DHA)',
#     'amount': 0.001,
#     'unitName': 'G'},
#    {'number': '626', 'name': 'MUFA 16:1', 'amount': 0.186, 'unitName': 'G'},
#    {'number': '627', 'name': 'PUFA 18:4', 'amount': 0.001, 'unitName': 'G'},
#    {'number': '628', 'name': 'MUFA 20:1', 'amount': 0.063, 'unitName': 'G'},
#    {'number': '629',
#     'name': 'PUFA 20:5 n-3 (EPA)',
#     'amount': 0.004,
#     'unitName': 'G'},
#    {'number': '630', 'name': 'MUFA 22:1', 'amount': 0.014, 'unitName': 'G'},
#    {'number': '631',
#     'name': 'PUFA 22:5 n-3 (DPA)',
#     'amount': 0.006,
#     'unitName': 'G'},
#    {'number': '645',
#     'name': 'Fatty acids, total monounsaturated',
#     'amount': 3.85,
#     'unitName': 'G'},
#    {'number': '646',
#     'name': 'Fatty acids, total polyunsaturated',
#     'amount': 2.06,
#     'unitName': 'G'}]},
#  {'fdcId': 2344125,
#   'description': 'Pizza with pepperoni, from restaurant or fast food, thick crust',
#   'dataType': 'Survey (FNDDS)',
#   'publicationDate': '2022-10-28',
#   'foodCode': '58106560',
#   'foodNutrients': [{'number': '203',
#     'name': 'Protein',
#     'amount': 11.5,
#     'unitName': 'G'},
#    {'number': '204',
#     'name': 'Total lipid (fat)',
#     'amount': 12.6,
#     'unitName': 'G'},
#    {'number': '205',
#     'name': 'Carbohydrate, by difference',
#     'amount': 31.8,
#     'unitName': 'G'},
#    {'number': '208', 'name': 'Energy', 'amount': 287, 'unitName': 'KCAL'},
#    {'number': '221', 'name': 'Alcohol, ethyl', 'amount': 0.0, 'unitName': 'G'},
#    {'number': '255', 'name': 'Water', 'amount': 41.5, 'unitName': 'G'},
#    {'number': '262', 'name': 'Caffeine', 'amount': 0.0, 'unitName': 'MG'},
#    {'number': '263', 'name': 'Theobromine', 'amount': 0.0, 'unitName': 'MG'},
#    {'number': '269',
#     'name': 'Sugars, total including NLEA',
#     'amount': 2.93,
#     'unitName': 'G'},
#    {'number': '291',
#     'name': 'Fiber, total dietary',
#     'amount': 2.2,
#     'unitName': 'G'},
#    {'number': '301', 'name': 'Calcium, Ca', 'amount': 148, 'unitName': 'MG'},
#    {'number': '303', 'name': 'Iron, Fe', 'amount': 2.55, 'unitName': 'MG'},
#    {'number': '304',
#     'name': 'Magnesium, Mg',
#     'amount': 23.0,
#     'unitName': 'MG'},
#    {'number': '305', 'name': 'Phosphorus, P', 'amount': 195, 'unitName': 'MG'},
#    {'number': '306', 'name': 'Potassium, K', 'amount': 189, 'unitName': 'MG'},
#    {'number': '307', 'name': 'Sodium, Na', 'amount': 684, 'unitName': 'MG'},
#    {'number': '309', 'name': 'Zinc, Zn', 'amount': 1.35, 'unitName': 'MG'},
#    {'number': '312', 'name': 'Copper, Cu', 'amount': 0.109, 'unitName': 'MG'},
#    {'number': '317', 'name': 'Selenium, Se', 'amount': 20.0, 'unitName': 'UG'},
#    {'number': '319', 'name': 'Retinol', 'amount': 63.0, 'unitName': 'UG'},
#    {'number': '320',
#     'name': 'Vitamin A, RAE',
#     'amount': 71.0,
#     'unitName': 'UG'},
#    {'number': '321',
#     'name': 'Carotene, beta',
#     'amount': 95.0,
#     'unitName': 'UG'},
#    {'number': '322',
#     'name': 'Carotene, alpha',
#     'amount': 0.0,
#     'unitName': 'UG'},
#    {'number': '323',
#     'name': 'Vitamin E (alpha-tocopherol)',
#     'amount': 0.87,
#     'unitName': 'MG'},
#    {'number': '328',
#     'name': 'Vitamin D (D2 + D3)',
#     'amount': 0.0,
#     'unitName': 'UG'},
#    {'number': '334',
#     'name': 'Cryptoxanthin, beta',
#     'amount': 0.0,
#     'unitName': 'UG'},
#    {'number': '337', 'name': 'Lycopene', 'amount': 1970.0, 'unitName': 'UG'},
#    {'number': '338',
#     'name': 'Lutein + zeaxanthin',
#     'amount': 23.0,
#     'unitName': 'UG'},
#    {'number': '401',
#     'name': 'Vitamin C, total ascorbic acid',
#     'amount': 0.7,
#     'unitName': 'MG'},
#    {'number': '404', 'name': 'Thiamin', 'amount': 0.39, 'unitName': 'MG'},
#    {'number': '405', 'name': 'Riboflavin', 'amount': 0.2, 'unitName': 'MG'},
#    {'number': '406', 'name': 'Niacin', 'amount': 3.5, 'unitName': 'MG'},
#    {'number': '415', 'name': 'Vitamin B-6', 'amount': 0.08, 'unitName': 'MG'},
#    {'number': '417', 'name': 'Folate, total', 'amount': 103, 'unitName': 'UG'},
#    {'number': '418', 'name': 'Vitamin B-12', 'amount': 0.51, 'unitName': 'UG'},
#    {'number': '421',
#     'name': 'Choline, total',
#     'amount': 24.8,
#     'unitName': 'MG'},
#    {'number': '430',
#     'name': 'Vitamin K (phylloquinone)',
#     'amount': 11.5,
#     'unitName': 'UG'},
#    {'number': '431', 'name': 'Folic acid', 'amount': 57.0, 'unitName': 'UG'},
#    {'number': '432', 'name': 'Folate, food', 'amount': 46.0, 'unitName': 'UG'},
#    {'number': '435', 'name': 'Folate, DFE', 'amount': 143, 'unitName': 'UG'},
#    {'number': '573',
#     'name': 'Vitamin E, added',
#     'amount': 0.0,
#     'unitName': 'MG'},
#    {'number': '578',
#     'name': 'Vitamin B-12, added',
#     'amount': 0.0,
#     'unitName': 'UG'},
#    {'number': '601', 'name': 'Cholesterol', 'amount': 24.0, 'unitName': 'MG'},
#    {'number': '606',
#     'name': 'Fatty acids, total saturated',
#     'amount': 4.84,
#     'unitName': 'G'},
#    {'number': '607', 'name': 'SFA 4:0', 'amount': 0.085, 'unitName': 'G'},
#    {'number': '608', 'name': 'SFA 6:0', 'amount': 0.066, 'unitName': 'G'},
#    {'number': '609', 'name': 'SFA 8:0', 'amount': 0.045, 'unitName': 'G'},
#    {'number': '610', 'name': 'SFA 10:0', 'amount': 0.115, 'unitName': 'G'},
#    {'number': '611', 'name': 'SFA 12:0', 'amount': 0.139, 'unitName': 'G'},
#    {'number': '612', 'name': 'SFA 14:0', 'amount': 0.53, 'unitName': 'G'},
#    {'number': '613', 'name': 'SFA 16:0', 'amount': 2.54, 'unitName': 'G'},
#    {'number': '614', 'name': 'SFA 18:0', 'amount': 1.14, 'unitName': 'G'},
#    {'number': '617', 'name': 'MUFA 18:1', 'amount': 3.4, 'unitName': 'G'},
#    {'number': '618', 'name': 'PUFA 18:2', 'amount': 2.6, 'unitName': 'G'},
#    {'number': '619', 'name': 'PUFA 18:3', 'amount': 0.303, 'unitName': 'G'},
#    {'number': '620', 'name': 'PUFA 20:4', 'amount': 0.023, 'unitName': 'G'},
#    {'number': '621',
#     'name': 'PUFA 22:6 n-3 (DHA)',
#     'amount': 0.0,
#     'unitName': 'G'},
#    {'number': '626', 'name': 'MUFA 16:1', 'amount': 0.18, 'unitName': 'G'},
#    {'number': '627', 'name': 'PUFA 18:4', 'amount': 0.002, 'unitName': 'G'},
#    {'number': '628', 'name': 'MUFA 20:1', 'amount': 0.065, 'unitName': 'G'},
#    {'number': '629',
#     'name': 'PUFA 20:5 n-3 (EPA)',
#     'amount': 0.003,
#     'unitName': 'G'},
#    {'number': '630', 'name': 'MUFA 22:1', 'amount': 0.011, 'unitName': 'G'},
#    {'number': '631',
#     'name': 'PUFA 22:5 n-3 (DPA)',
#     'amount': 0.005,
#     'unitName': 'G'},
#    {'number': '645',
#     'name': 'Fatty acids, total monounsaturated',
#     'amount': 3.73,
#     'unitName': 'G'},
#    {'number': '646',
#     'name': 'Fatty acids, total polyunsaturated',
#     'amount': 2.98,
#     'unitName': 'G'}]},
#  {'fdcId': 2344123,
#   'description': 'Pizza with pepperoni, from restaurant or fast food, thin crust',
#   'dataType': 'Survey (FNDDS)',
#   'publicationDate': '2022-10-28',
#   'foodCode': '58106550',
#   'foodNutrients': [{'number': '203',
#     'name': 'Protein',
#     'amount': 14.0,
#     'unitName': 'G'},
#    {'number': '204',
#     'name': 'Total lipid (fat)',
#     'amount': 17.6,
#     'unitName': 'G'},
#    {'number': '205',
#     'name': 'Carbohydrate, by difference',
#     'amount': 29.0,
#     'unitName': 'G'},
#    {'number': '208', 'name': 'Energy', 'amount': 331, 'unitName': 'KCAL'},
#    {'number': '221', 'name': 'Alcohol, ethyl', 'amount': 0.0, 'unitName': 'G'},
#    {'number': '255', 'name': 'Water', 'amount': 36.0, 'unitName': 'G'},
#    {'number': '262', 'name': 'Caffeine', 'amount': 0.0, 'unitName': 'MG'},
#    {'number': '263', 'name': 'Theobromine', 'amount': 0.0, 'unitName': 'MG'},
#    {'number': '269',
#     'name': 'Sugars, total including NLEA',
#     'amount': 3.22,
#     'unitName': 'G'},
#    {'number': '291',
#     'name': 'Fiber, total dietary',
#     'amount': 2.3,
#     'unitName': 'G'},
#    {'number': '301', 'name': 'Calcium, Ca', 'amount': 216, 'unitName': 'MG'},
#    {'number': '303', 'name': 'Iron, Fe', 'amount': 1.95, 'unitName': 'MG'},
#    {'number': '304',
#     'name': 'Magnesium, Mg',
#     'amount': 25.0,
#     'unitName': 'MG'},
#    {'number': '305', 'name': 'Phosphorus, P', 'amount': 253, 'unitName': 'MG'},
#    {'number': '306', 'name': 'Potassium, K', 'amount': 223, 'unitName': 'MG'},
#    {'number': '307', 'name': 'Sodium, Na', 'amount': 875, 'unitName': 'MG'},
#    {'number': '309', 'name': 'Zinc, Zn', 'amount': 1.64, 'unitName': 'MG'},
#    {'number': '312', 'name': 'Copper, Cu', 'amount': 0.11, 'unitName': 'MG'},
#    {'number': '317', 'name': 'Selenium, Se', 'amount': 24.5, 'unitName': 'UG'},
#    {'number': '319', 'name': 'Retinol', 'amount': 62.0, 'unitName': 'UG'},
#    {'number': '320',
#     'name': 'Vitamin A, RAE',
#     'amount': 70.0,
#     'unitName': 'UG'},
#    {'number': '321',
#     'name': 'Carotene, beta',
#     'amount': 94.0,
#     'unitName': 'UG'},
#    {'number': '322',
#     'name': 'Carotene, alpha',
#     'amount': 0.0,
#     'unitName': 'UG'},
#    {'number': '323',
#     'name': 'Vitamin E (alpha-tocopherol)',
#     'amount': 1.29,
#     'unitName': 'MG'},
#    {'number': '328',
#     'name': 'Vitamin D (D2 + D3)',
#     'amount': 0.0,
#     'unitName': 'UG'},
#    {'number': '334',
#     'name': 'Cryptoxanthin, beta',
#     'amount': 0.0,
#     'unitName': 'UG'},
#    {'number': '337', 'name': 'Lycopene', 'amount': 1960.0, 'unitName': 'UG'},
#    {'number': '338',
#     'name': 'Lutein + zeaxanthin',
#     'amount': 24.0,
#     'unitName': 'UG'},
#    {'number': '401',
#     'name': 'Vitamin C, total ascorbic acid',
#     'amount': 2.0,
#     'unitName': 'MG'},
#    {'number': '404', 'name': 'Thiamin', 'amount': 0.225, 'unitName': 'MG'},
#    {'number': '405', 'name': 'Riboflavin', 'amount': 0.17, 'unitName': 'MG'},
#    {'number': '406', 'name': 'Niacin', 'amount': 3.31, 'unitName': 'MG'},
#    {'number': '415', 'name': 'Vitamin B-6', 'amount': 0.095, 'unitName': 'MG'},
#    {'number': '417',
#     'name': 'Folate, total',
#     'amount': 92.0,
#     'unitName': 'UG'},
#    {'number': '418', 'name': 'Vitamin B-12', 'amount': 0.76, 'unitName': 'UG'},
#    {'number': '421',
#     'name': 'Choline, total',
#     'amount': 37.5,
#     'unitName': 'MG'},
#    {'number': '430',
#     'name': 'Vitamin K (phylloquinone)',
#     'amount': 9.5,
#     'unitName': 'UG'},
#    {'number': '431', 'name': 'Folic acid', 'amount': 56.0, 'unitName': 'UG'},
#    {'number': '432', 'name': 'Folate, food', 'amount': 36.0, 'unitName': 'UG'},
#    {'number': '435', 'name': 'Folate, DFE', 'amount': 131, 'unitName': 'UG'},
#    {'number': '573',
#     'name': 'Vitamin E, added',
#     'amount': 0.0,
#     'unitName': 'MG'},
#    {'number': '578',
#     'name': 'Vitamin B-12, added',
#     'amount': 0.0,
#     'unitName': 'UG'},
#    {'number': '601', 'name': 'Cholesterol', 'amount': 37.0, 'unitName': 'MG'},
#    {'number': '606',
#     'name': 'Fatty acids, total saturated',
#     'amount': 7.12,
#     'unitName': 'G'},
#    {'number': '607', 'name': 'SFA 4:0', 'amount': 0.11, 'unitName': 'G'},
#    {'number': '608', 'name': 'SFA 6:0', 'amount': 0.091, 'unitName': 'G'},
#    {'number': '609', 'name': 'SFA 8:0', 'amount': 0.063, 'unitName': 'G'},
#    {'number': '610', 'name': 'SFA 10:0', 'amount': 0.162, 'unitName': 'G'},
#    {'number': '611', 'name': 'SFA 12:0', 'amount': 0.196, 'unitName': 'G'},
#    {'number': '612', 'name': 'SFA 14:0', 'amount': 0.772, 'unitName': 'G'},
#    {'number': '613', 'name': 'SFA 16:0', 'amount': 3.75, 'unitName': 'G'},
#    {'number': '614', 'name': 'SFA 18:0', 'amount': 1.72, 'unitName': 'G'},
#    {'number': '617', 'name': 'MUFA 18:1', 'amount': 5.11, 'unitName': 'G'},
#    {'number': '618', 'name': 'PUFA 18:2', 'amount': 3.18, 'unitName': 'G'},
#    {'number': '619', 'name': 'PUFA 18:3', 'amount': 0.319, 'unitName': 'G'},
#    {'number': '620', 'name': 'PUFA 20:4', 'amount': 0.036, 'unitName': 'G'},
#    {'number': '621',
#     'name': 'PUFA 22:6 n-3 (DHA)',
#     'amount': 0.001,
#     'unitName': 'G'},
#    {'number': '626', 'name': 'MUFA 16:1', 'amount': 0.278, 'unitName': 'G'},
#    {'number': '627', 'name': 'PUFA 18:4', 'amount': 0.002, 'unitName': 'G'},
#    {'number': '628', 'name': 'MUFA 20:1', 'amount': 0.094, 'unitName': 'G'},
#    {'number': '629',
#     'name': 'PUFA 20:5 n-3 (EPA)',
#     'amount': 0.005,
#     'unitName': 'G'},
#    {'number': '630', 'name': 'MUFA 22:1', 'amount': 0.021, 'unitName': 'G'},
#    {'number': '631',
#     'name': 'PUFA 22:5 n-3 (DPA)',
#     'amount': 0.008,
#     'unitName': 'G'},
#    {'number': '645',
#     'name': 'Fatty acids, total monounsaturated',
#     'amount': 5.62,
#     'unitName': 'G'},
#    {'number': '646',
#     'name': 'Fatty acids, total polyunsaturated',
#     'amount': 3.62,
#     'unitName': 'G'}]},
#  {'fdcId': 2344129,
#   'description': 'Pizza with pepperoni, from school lunch, thick crust',
#   'dataType': 'Survey (FNDDS)',
#   'publicationDate': '2022-10-28',
#   'foodCode': '58106580',
#   'foodNutrients': [{'number': '203',
#     'name': 'Protein',
#     'amount': 14.4,
#     'unitName': 'G'},
#    {'number': '204',
#     'name': 'Total lipid (fat)',
#     'amount': 9.82,
#     'unitName': 'G'},
#    {'number': '205',
#     'name': 'Carbohydrate, by difference',
#     'amount': 28.3,
#     'unitName': 'G'},
#    {'number': '208', 'name': 'Energy', 'amount': 259, 'unitName': 'KCAL'},
#    {'number': '221', 'name': 'Alcohol, ethyl', 'amount': 0.0, 'unitName': 'G'},
#    {'number': '255', 'name': 'Water', 'amount': 45.3, 'unitName': 'G'},
#    {'number': '262', 'name': 'Caffeine', 'amount': 0.0, 'unitName': 'MG'},
#    {'number': '263', 'name': 'Theobromine', 'amount': 0.0, 'unitName': 'MG'},
#    {'number': '269',
#     'name': 'Sugars, total including NLEA',
#     'amount': 4.03,
#     'unitName': 'G'},
#    {'number': '291',
#     'name': 'Fiber, total dietary',
#     'amount': 4.3,
#     'unitName': 'G'},
#    {'number': '301', 'name': 'Calcium, Ca', 'amount': 155, 'unitName': 'MG'},
#    {'number': '303', 'name': 'Iron, Fe', 'amount': 2.53, 'unitName': 'MG'},
#    {'number': '304',
#     'name': 'Magnesium, Mg',
#     'amount': 41.0,
#     'unitName': 'MG'},
#    {'number': '305', 'name': 'Phosphorus, P', 'amount': 305, 'unitName': 'MG'},
#    {'number': '306', 'name': 'Potassium, K', 'amount': 308, 'unitName': 'MG'},
#    {'number': '307', 'name': 'Sodium, Na', 'amount': 474, 'unitName': 'MG'},
#    {'number': '309', 'name': 'Zinc, Zn', 'amount': 1.93, 'unitName': 'MG'},
#    {'number': '312', 'name': 'Copper, Cu', 'amount': 0.079, 'unitName': 'MG'},
#    {'number': '317', 'name': 'Selenium, Se', 'amount': 22.0, 'unitName': 'UG'},
#    {'number': '319', 'name': 'Retinol', 'amount': 36.0, 'unitName': 'UG'},
#    {'number': '320',
#     'name': 'Vitamin A, RAE',
#     'amount': 43.0,
#     'unitName': 'UG'},
#    {'number': '321',
#     'name': 'Carotene, beta',
#     'amount': 83.0,
#     'unitName': 'UG'},
#    {'number': '322',
#     'name': 'Carotene, alpha',
#     'amount': 0.0,
#     'unitName': 'UG'},
#    {'number': '323',
#     'name': 'Vitamin E (alpha-tocopherol)',
#     'amount': 0.81,
#     'unitName': 'MG'},
#    {'number': '328',
#     'name': 'Vitamin D (D2 + D3)',
#     'amount': 0.0,
#     'unitName': 'UG'},
#    {'number': '334',
#     'name': 'Cryptoxanthin, beta',
#     'amount': 0.0,
#     'unitName': 'UG'},
#    {'number': '337', 'name': 'Lycopene', 'amount': 1840.0, 'unitName': 'UG'},
#    {'number': '338',
#     'name': 'Lutein + zeaxanthin',
#     'amount': 21.0,
#     'unitName': 'UG'},
#    {'number': '401',
#     'name': 'Vitamin C, total ascorbic acid',
#     'amount': 0.2,
#     'unitName': 'MG'},
#    {'number': '404', 'name': 'Thiamin', 'amount': 0.211, 'unitName': 'MG'},
#    {'number': '405', 'name': 'Riboflavin', 'amount': 0.284, 'unitName': 'MG'},
#    {'number': '406', 'name': 'Niacin', 'amount': 2.52, 'unitName': 'MG'},
#    {'number': '415', 'name': 'Vitamin B-6', 'amount': 0.143, 'unitName': 'MG'},
#    {'number': '417',
#     'name': 'Folate, total',
#     'amount': 59.0,
#     'unitName': 'UG'},
#    {'number': '418', 'name': 'Vitamin B-12', 'amount': 1.19, 'unitName': 'UG'},
#    {'number': '421',
#     'name': 'Choline, total',
#     'amount': 23.2,
#     'unitName': 'MG'},
#    {'number': '430',
#     'name': 'Vitamin K (phylloquinone)',
#     'amount': 10.8,
#     'unitName': 'UG'},
#    {'number': '431', 'name': 'Folic acid', 'amount': 39.0, 'unitName': 'UG'},
#    {'number': '432', 'name': 'Folate, food', 'amount': 20.0, 'unitName': 'UG'},
#    {'number': '435', 'name': 'Folate, DFE', 'amount': 87.0, 'unitName': 'UG'},
#    {'number': '573',
#     'name': 'Vitamin E, added',
#     'amount': 0.0,
#     'unitName': 'MG'},
#    {'number': '578',
#     'name': 'Vitamin B-12, added',
#     'amount': 0.0,
#     'unitName': 'UG'},
#    {'number': '601', 'name': 'Cholesterol', 'amount': 24.0, 'unitName': 'MG'},
#    {'number': '606',
#     'name': 'Fatty acids, total saturated',
#     'amount': 4.22,
#     'unitName': 'G'},
#    {'number': '607', 'name': 'SFA 4:0', 'amount': 0.12, 'unitName': 'G'},
#    {'number': '608', 'name': 'SFA 6:0', 'amount': 0.101, 'unitName': 'G'},
#    {'number': '609', 'name': 'SFA 8:0', 'amount': 0.063, 'unitName': 'G'},
#    {'number': '610', 'name': 'SFA 10:0', 'amount': 0.153, 'unitName': 'G'},
#    {'number': '611', 'name': 'SFA 12:0', 'amount': 0.174, 'unitName': 'G'},
#    {'number': '612', 'name': 'SFA 14:0', 'amount': 0.6, 'unitName': 'G'},
#    {'number': '613', 'name': 'SFA 16:0', 'amount': 2.11, 'unitName': 'G'},
#    {'number': '614', 'name': 'SFA 18:0', 'amount': 0.894, 'unitName': 'G'},
#    {'number': '617', 'name': 'MUFA 18:1', 'amount': 2.32, 'unitName': 'G'},
#    {'number': '618', 'name': 'PUFA 18:2', 'amount': 0.701, 'unitName': 'G'},
#    {'number': '619', 'name': 'PUFA 18:3', 'amount': 0.062, 'unitName': 'G'},
#    {'number': '620', 'name': 'PUFA 20:4', 'amount': 0.014, 'unitName': 'G'},
#    {'number': '621',
#     'name': 'PUFA 22:6 n-3 (DHA)',
#     'amount': 0.0,
#     'unitName': 'G'},
#    {'number': '626', 'name': 'MUFA 16:1', 'amount': 0.149, 'unitName': 'G'},
#    {'number': '627', 'name': 'PUFA 18:4', 'amount': 0.0, 'unitName': 'G'},
#    {'number': '628', 'name': 'MUFA 20:1', 'amount': 0.024, 'unitName': 'G'},
#    {'number': '629',
#     'name': 'PUFA 20:5 n-3 (EPA)',
#     'amount': 0.002,
#     'unitName': 'G'},
#    {'number': '630', 'name': 'MUFA 22:1', 'amount': 0.0, 'unitName': 'G'},
#    {'number': '631',
#     'name': 'PUFA 22:5 n-3 (DPA)',
#     'amount': 0.004,
#     'unitName': 'G'},
#    {'number': '645',
#     'name': 'Fatty acids, total monounsaturated',
#     'amount': 2.89,
#     'unitName': 'G'},
#    {'number': '646',
#     'name': 'Fatty acids, total polyunsaturated',
#     'amount': 1.21,
#     'unitName': 'G'}]},
#  {'fdcId': 2344127,
#   'description': 'Pizza with pepperoni, from school lunch, thin crust',
#   'dataType': 'Survey (FNDDS)',
#   'publicationDate': '2022-10-28',
#   'foodCode': '58106570',
#   'foodNutrients': [{'number': '203',
#     'name': 'Protein',
#     'amount': 12.8,
#     'unitName': 'G'},
#    {'number': '204',
#     'name': 'Total lipid (fat)',
#     'amount': 8.62,
#     'unitName': 'G'},
#    {'number': '205',
#     'name': 'Carbohydrate, by difference',
#     'amount': 31.2,
#     'unitName': 'G'},
#    {'number': '208', 'name': 'Energy', 'amount': 254, 'unitName': 'KCAL'},
#    {'number': '221', 'name': 'Alcohol, ethyl', 'amount': 0.0, 'unitName': 'G'},
#    {'number': '255', 'name': 'Water', 'amount': 44.9, 'unitName': 'G'},
#    {'number': '262', 'name': 'Caffeine', 'amount': 0.0, 'unitName': 'MG'},
#    {'number': '263', 'name': 'Theobromine', 'amount': 0.0, 'unitName': 'MG'},
#    {'number': '269',
#     'name': 'Sugars, total including NLEA',
#     'amount': 7.62,
#     'unitName': 'G'},
#    {'number': '291',
#     'name': 'Fiber, total dietary',
#     'amount': 4.3,
#     'unitName': 'G'},
#    {'number': '301', 'name': 'Calcium, Ca', 'amount': 202, 'unitName': 'MG'},
#    {'number': '303', 'name': 'Iron, Fe', 'amount': 2.74, 'unitName': 'MG'},
#    {'number': '304',
#     'name': 'Magnesium, Mg',
#     'amount': 51.0,
#     'unitName': 'MG'},
#    {'number': '305', 'name': 'Phosphorus, P', 'amount': 316, 'unitName': 'MG'},
#    {'number': '306', 'name': 'Potassium, K', 'amount': 382, 'unitName': 'MG'},
#    {'number': '307', 'name': 'Sodium, Na', 'amount': 495, 'unitName': 'MG'},
#    {'number': '309', 'name': 'Zinc, Zn', 'amount': 2.51, 'unitName': 'MG'},
#    {'number': '312', 'name': 'Copper, Cu', 'amount': 0.1, 'unitName': 'MG'},
#    {'number': '317', 'name': 'Selenium, Se', 'amount': 23.4, 'unitName': 'UG'},
#    {'number': '319', 'name': 'Retinol', 'amount': 67.0, 'unitName': 'UG'},
#    {'number': '320',
#     'name': 'Vitamin A, RAE',
#     'amount': 75.0,
#     'unitName': 'UG'},
#    {'number': '321',
#     'name': 'Carotene, beta',
#     'amount': 106,
#     'unitName': 'UG'},
#    {'number': '322',
#     'name': 'Carotene, alpha',
#     'amount': 0.0,
#     'unitName': 'UG'},
#    {'number': '323',
#     'name': 'Vitamin E (alpha-tocopherol)',
#     'amount': 0.8,
#     'unitName': 'MG'},
#    {'number': '328',
#     'name': 'Vitamin D (D2 + D3)',
#     'amount': 0.0,
#     'unitName': 'UG'},
#    {'number': '334',
#     'name': 'Cryptoxanthin, beta',
#     'amount': 0.0,
#     'unitName': 'UG'},
#    {'number': '337', 'name': 'Lycopene', 'amount': 1960.0, 'unitName': 'UG'},
#    {'number': '338',
#     'name': 'Lutein + zeaxanthin',
#     'amount': 24.0,
#     'unitName': 'UG'},
#    {'number': '401',
#     'name': 'Vitamin C, total ascorbic acid',
#     'amount': 0.0,
#     'unitName': 'MG'},
#    {'number': '404', 'name': 'Thiamin', 'amount': 0.347, 'unitName': 'MG'},
#    {'number': '405', 'name': 'Riboflavin', 'amount': 0.337, 'unitName': 'MG'},
#    {'number': '406', 'name': 'Niacin', 'amount': 3.73, 'unitName': 'MG'},
#    {'number': '415', 'name': 'Vitamin B-6', 'amount': 0.187, 'unitName': 'MG'},
#    {'number': '417',
#     'name': 'Folate, total',
#     'amount': 55.0,
#     'unitName': 'UG'},
#    {'number': '418', 'name': 'Vitamin B-12', 'amount': 2.16, 'unitName': 'UG'},
#    {'number': '421',
#     'name': 'Choline, total',
#     'amount': 37.7,
#     'unitName': 'MG'},
#    {'number': '430',
#     'name': 'Vitamin K (phylloquinone)',
#     'amount': 5.2,
#     'unitName': 'UG'},
#    {'number': '431', 'name': 'Folic acid', 'amount': 36.0, 'unitName': 'UG'},
#    {'number': '432', 'name': 'Folate, food', 'amount': 19.0, 'unitName': 'UG'},
#    {'number': '435', 'name': 'Folate, DFE', 'amount': 80.0, 'unitName': 'UG'},
#    {'number': '573',
#     'name': 'Vitamin E, added',
#     'amount': 0.0,
#     'unitName': 'MG'},
#    {'number': '578',
#     'name': 'Vitamin B-12, added',
#     'amount': 0.0,
#     'unitName': 'UG'},
#    {'number': '601', 'name': 'Cholesterol', 'amount': 24.0, 'unitName': 'MG'},
#    {'number': '606',
#     'name': 'Fatty acids, total saturated',
#     'amount': 2.81,
#     'unitName': 'G'},
#    {'number': '607', 'name': 'SFA 4:0', 'amount': 0.089, 'unitName': 'G'},
#    {'number': '608', 'name': 'SFA 6:0', 'amount': 0.075, 'unitName': 'G'},
#    {'number': '609', 'name': 'SFA 8:0', 'amount': 0.047, 'unitName': 'G'},
#    {'number': '610', 'name': 'SFA 10:0', 'amount': 0.114, 'unitName': 'G'},
#    {'number': '611', 'name': 'SFA 12:0', 'amount': 0.129, 'unitName': 'G'},
#    {'number': '612', 'name': 'SFA 14:0', 'amount': 0.422, 'unitName': 'G'},
#    {'number': '613', 'name': 'SFA 16:0', 'amount': 1.32, 'unitName': 'G'},
#    {'number': '614', 'name': 'SFA 18:0', 'amount': 0.521, 'unitName': 'G'},
#    {'number': '617', 'name': 'MUFA 18:1', 'amount': 1.9, 'unitName': 'G'},
#    {'number': '618', 'name': 'PUFA 18:2', 'amount': 1.95, 'unitName': 'G'},
#    {'number': '619', 'name': 'PUFA 18:3', 'amount': 0.188, 'unitName': 'G'},
#    {'number': '620', 'name': 'PUFA 20:4', 'amount': 0.033, 'unitName': 'G'},
#    {'number': '621',
#     'name': 'PUFA 22:6 n-3 (DHA)',
#     'amount': 0.0,
#     'unitName': 'G'},
#    {'number': '626', 'name': 'MUFA 16:1', 'amount': 0.118, 'unitName': 'G'},
#    {'number': '627', 'name': 'PUFA 18:4', 'amount': 0.0, 'unitName': 'G'},
#    {'number': '628', 'name': 'MUFA 20:1', 'amount': 0.017, 'unitName': 'G'},
#    {'number': '629',
#     'name': 'PUFA 20:5 n-3 (EPA)',
#     'amount': 0.006,
#     'unitName': 'G'},
#    {'number': '630', 'name': 'MUFA 22:1', 'amount': 0.0, 'unitName': 'G'},
#    {'number': '631',
#     'name': 'PUFA 22:5 n-3 (DPA)',
#     'amount': 0.011,
#     'unitName': 'G'},
#    {'number': '645',
#     'name': 'Fatty acids, total monounsaturated',
#     'amount': 2.12,
#     'unitName': 'G'},
#    {'number': '646',
#     'name': 'Fatty acids, total polyunsaturated',
#     'amount': 2.23,
#     'unitName': 'G'}]},
#  {'fdcId': 2344126,
#   'description': 'Pizza with pepperoni, stuffed crust',
#   'dataType': 'Survey (FNDDS)',
#   'publicationDate': '2022-10-28',
#   'foodCode': '58106565',
#   'foodNutrients': [{'number': '203',
#     'name': 'Protein',
#     'amount': 12.9,
#     'unitName': 'G'},
#    {'number': '204',
#     'name': 'Total lipid (fat)',
#     'amount': 15.0,
#     'unitName': 'G'},
#    {'number': '205',
#     'name': 'Carbohydrate, by difference',
#     'amount': 27.2,
#     'unitName': 'G'},
#    {'number': '208', 'name': 'Energy', 'amount': 296, 'unitName': 'KCAL'},
#    {'number': '221', 'name': 'Alcohol, ethyl', 'amount': 0.0, 'unitName': 'G'},
#    {'number': '255', 'name': 'Water', 'amount': 41.9, 'unitName': 'G'},
#    {'number': '262', 'name': 'Caffeine', 'amount': 0.0, 'unitName': 'MG'},
#    {'number': '263', 'name': 'Theobromine', 'amount': 0.0, 'unitName': 'MG'},
#    {'number': '269',
#     'name': 'Sugars, total including NLEA',
#     'amount': 2.62,
#     'unitName': 'G'},
#    {'number': '291',
#     'name': 'Fiber, total dietary',
#     'amount': 1.5,
#     'unitName': 'G'},
#    {'number': '301', 'name': 'Calcium, Ca', 'amount': 217, 'unitName': 'MG'},
#    {'number': '303', 'name': 'Iron, Fe', 'amount': 1.97, 'unitName': 'MG'},
#    {'number': '304',
#     'name': 'Magnesium, Mg',
#     'amount': 22.0,
#     'unitName': 'MG'},
#    {'number': '305', 'name': 'Phosphorus, P', 'amount': 240, 'unitName': 'MG'},
#    {'number': '306', 'name': 'Potassium, K', 'amount': 233, 'unitName': 'MG'},
#    {'number': '307', 'name': 'Sodium, Na', 'amount': 709, 'unitName': 'MG'},
#    {'number': '309', 'name': 'Zinc, Zn', 'amount': 1.58, 'unitName': 'MG'},
#    {'number': '312', 'name': 'Copper, Cu', 'amount': 0.082, 'unitName': 'MG'},
#    {'number': '317', 'name': 'Selenium, Se', 'amount': 17.3, 'unitName': 'UG'},
#    {'number': '319', 'name': 'Retinol', 'amount': 99.0, 'unitName': 'UG'},
#    {'number': '320',
#     'name': 'Vitamin A, RAE',
#     'amount': 106,
#     'unitName': 'UG'},
#    {'number': '321',
#     'name': 'Carotene, beta',
#     'amount': 79.0,
#     'unitName': 'UG'},
#    {'number': '322',
#     'name': 'Carotene, alpha',
#     'amount': 1.0,
#     'unitName': 'UG'},
#    {'number': '323',
#     'name': 'Vitamin E (alpha-tocopherol)',
#     'amount': 0.7,
#     'unitName': 'MG'},
#    {'number': '328',
#     'name': 'Vitamin D (D2 + D3)',
#     'amount': 0.1,
#     'unitName': 'UG'},
#    {'number': '334',
#     'name': 'Cryptoxanthin, beta',
#     'amount': 0.0,
#     'unitName': 'UG'},
#    {'number': '337', 'name': 'Lycopene', 'amount': 844, 'unitName': 'UG'},
#    {'number': '338',
#     'name': 'Lutein + zeaxanthin',
#     'amount': 41.0,
#     'unitName': 'UG'},
#    {'number': '401',
#     'name': 'Vitamin C, total ascorbic acid',
#     'amount': 2.8,
#     'unitName': 'MG'},
#    {'number': '404', 'name': 'Thiamin', 'amount': 0.318, 'unitName': 'MG'},
#    {'number': '405', 'name': 'Riboflavin', 'amount': 0.326, 'unitName': 'MG'},
#    {'number': '406', 'name': 'Niacin', 'amount': 3.88, 'unitName': 'MG'},
#    {'number': '415', 'name': 'Vitamin B-6', 'amount': 0.143, 'unitName': 'MG'},
#    {'number': '417',
#     'name': 'Folate, total',
#     'amount': 82.0,
#     'unitName': 'UG'},
#    {'number': '418', 'name': 'Vitamin B-12', 'amount': 0.49, 'unitName': 'UG'},
#    {'number': '421',
#     'name': 'Choline, total',
#     'amount': 20.6,
#     'unitName': 'MG'},
#    {'number': '430',
#     'name': 'Vitamin K (phylloquinone)',
#     'amount': 8.1,
#     'unitName': 'UG'},
#    {'number': '431', 'name': 'Folic acid', 'amount': 45.0, 'unitName': 'UG'},
#    {'number': '432', 'name': 'Folate, food', 'amount': 37.0, 'unitName': 'UG'},
#    {'number': '435', 'name': 'Folate, DFE', 'amount': 113, 'unitName': 'UG'},
#    {'number': '573',
#     'name': 'Vitamin E, added',
#     'amount': 0.0,
#     'unitName': 'MG'},
#    {'number': '578',
#     'name': 'Vitamin B-12, added',
#     'amount': 0.0,
#     'unitName': 'UG'},
#    {'number': '601', 'name': 'Cholesterol', 'amount': 37.0, 'unitName': 'MG'},
#    {'number': '606',
#     'name': 'Fatty acids, total saturated',
#     'amount': 6.98,
#     'unitName': 'G'},
#    {'number': '607', 'name': 'SFA 4:0', 'amount': 0.158, 'unitName': 'G'},
#    {'number': '608', 'name': 'SFA 6:0', 'amount': 0.129, 'unitName': 'G'},
#    {'number': '609', 'name': 'SFA 8:0', 'amount': 0.082, 'unitName': 'G'},
#    {'number': '610', 'name': 'SFA 10:0', 'amount': 0.213, 'unitName': 'G'},
#    {'number': '611', 'name': 'SFA 12:0', 'amount': 0.251, 'unitName': 'G'},
#    {'number': '612', 'name': 'SFA 14:0', 'amount': 0.911, 'unitName': 'G'},
#    {'number': '613', 'name': 'SFA 16:0', 'amount': 3.55, 'unitName': 'G'},
#    {'number': '614', 'name': 'SFA 18:0', 'amount': 1.46, 'unitName': 'G'},
#    {'number': '617', 'name': 'MUFA 18:1', 'amount': 4.05, 'unitName': 'G'},
#    {'number': '618', 'name': 'PUFA 18:2', 'amount': 1.6, 'unitName': 'G'},
#    {'number': '619', 'name': 'PUFA 18:3', 'amount': 0.156, 'unitName': 'G'},
#    {'number': '620', 'name': 'PUFA 20:4', 'amount': 0.026, 'unitName': 'G'},
#    {'number': '621',
#     'name': 'PUFA 22:6 n-3 (DHA)',
#     'amount': 0.0,
#     'unitName': 'G'},
#    {'number': '626', 'name': 'MUFA 16:1', 'amount': 0.285, 'unitName': 'G'},
#    {'number': '627', 'name': 'PUFA 18:4', 'amount': 0.0, 'unitName': 'G'},
#    {'number': '628', 'name': 'MUFA 20:1', 'amount': 0.049, 'unitName': 'G'},
#    {'number': '629',
#     'name': 'PUFA 20:5 n-3 (EPA)',
#     'amount': 0.003,
#     'unitName': 'G'},
#    {'number': '630', 'name': 'MUFA 22:1', 'amount': 0.001, 'unitName': 'G'},
#    {'number': '631',
#     'name': 'PUFA 22:5 n-3 (DPA)',
#     'amount': 0.007,
#     'unitName': 'G'},
#    {'number': '645',
#     'name': 'Fatty acids, total monounsaturated',
#     'amount': 4.53,
#     'unitName': 'G'},
#    {'number': '646',
#     'name': 'Fatty acids, total polyunsaturated',
#     'amount': 1.83,
#     'unitName': 'G'}]},
#  {'fdcId': 2344182,
#   'description': 'Pizza, cheese and vegetables, gluten-free thick crust',
#   'dataType': 'Survey (FNDDS)',
#   'publicationDate': '2022-10-28',
#   'foodCode': '58109150',
#   'foodNutrients': [{'number': '203',
#     'name': 'Protein',
#     'amount': 6.68,
#     'unitName': 'G'},
#    {'number': '204',
#     'name': 'Total lipid (fat)',
#     'amount': 10.5,
#     'unitName': 'G'},
#    {'number': '205',
#     'name': 'Carbohydrate, by difference',
#     'amount': 26.7,
#     'unitName': 'G'},
#    {'number': '208', 'name': 'Energy', 'amount': 228, 'unitName': 'KCAL'},
#    {'number': '221', 'name': 'Alcohol, ethyl', 'amount': 0.0, 'unitName': 'G'},
#    {'number': '255', 'name': 'Water', 'amount': 54.2, 'unitName': 'G'},
#    {'number': '262', 'name': 'Caffeine', 'amount': 0.0, 'unitName': 'MG'},
#    {'number': '263', 'name': 'Theobromine', 'amount': 0.0, 'unitName': 'MG'},
#    {'number': '269',
#     'name': 'Sugars, total including NLEA',
#     'amount': 3.17,
#     'unitName': 'G'},
#    {'number': '291',
#     'name': 'Fiber, total dietary',
#     'amount': 2.7,
#     'unitName': 'G'},
#    {'number': '301', 'name': 'Calcium, Ca', 'amount': 202, 'unitName': 'MG'},
#    {'number': '303', 'name': 'Iron, Fe', 'amount': 1.89, 'unitName': 'MG'},
#    {'number': '304',
#     'name': 'Magnesium, Mg',
#     'amount': 14.0,
#     'unitName': 'MG'},
#    {'number': '305', 'name': 'Phosphorus, P', 'amount': 126, 'unitName': 'MG'},
#    {'number': '306', 'name': 'Potassium, K', 'amount': 111, 'unitName': 'MG'},
#    {'number': '307', 'name': 'Sodium, Na', 'amount': 439, 'unitName': 'MG'},
#    {'number': '309', 'name': 'Zinc, Zn', 'amount': 0.93, 'unitName': 'MG'},
#    {'number': '312', 'name': 'Copper, Cu', 'amount': 0.075, 'unitName': 'MG'},
#    {'number': '317', 'name': 'Selenium, Se', 'amount': 5.1, 'unitName': 'UG'},
# ...
#    {'number': '305',
#     'name': 'Phosphorus, P',
#     'amount': 49.0,
#     'unitName': 'MG'},
#    {'number': '306', 'name': 'Potassium, K', 'amount': 181, 'unitName': 'MG'},
#    {'number': '307', 'name': 'Sodium, Na', 'amount': 267, 'unitName': 'MG'},
#    {'number': '309', 'name': 'Zinc, Zn', 'amount': 0.44, 'unitName': 'MG'},
#    {'number': '312', 'name': 'Copper, Cu', 'amount': 0.035, 'unitName': 'MG'},
#    {'number': '317', 'name': 'Selenium, Se', 'amount': 7.0, 'unitName': 'UG'},
#    {'number': '319', 'name': 'Retinol', 'amount': 0.0, 'unitName': 'UG'},
#    {'number': '320',
#     'name': 'Vitamin A, RAE',
#     'amount': 33.0,
#     'unitName': 'UG'},
#    {'number': '321',
#     'name': 'Carotene, beta',
#     'amount': 342,
#     'unitName': 'UG'},
#    {'number': '322',
#     'name': 'Carotene, alpha',
#     'amount': 101,
#     'unitName': 'UG'},
#    {'number': '323',
#     'name': 'Vitamin E (alpha-tocopherol)',
#     'amount': 0.22,
#     'unitName': 'MG'},
#    {'number': '328',
#     'name': 'Vitamin D (D2 + D3)',
#     'amount': 0.1,
#     'unitName': 'UG'},
#    {'number': '334',
#     'name': 'Cryptoxanthin, beta',
#     'amount': 4.0,
#     'unitName': 'UG'},
#    {'number': '337', 'name': 'Lycopene', 'amount': 208, 'unitName': 'UG'},
#    {'number': '338',
#     'name': 'Lutein + zeaxanthin',
#     'amount': 179,
#     'unitName': 'UG'},
#    {'number': '401',
#     'name': 'Vitamin C, total ascorbic acid',
#     'amount': 4.3,
#     'unitName': 'MG'},
#    {'number': '404', 'name': 'Thiamin', 'amount': 0.108, 'unitName': 'MG'},
#    {'number': '405', 'name': 'Riboflavin', 'amount': 0.066, 'unitName': 'MG'},
#    {'number': '406', 'name': 'Niacin', 'amount': 1.42, 'unitName': 'MG'},
#    {'number': '415', 'name': 'Vitamin B-6', 'amount': 0.104, 'unitName': 'MG'},
#    {'number': '417',
#     'name': 'Folate, total',
#     'amount': 10.0,
#     'unitName': 'UG'},
#    {'number': '418', 'name': 'Vitamin B-12', 'amount': 0.12, 'unitName': 'UG'},
#    {'number': '421',
#     'name': 'Choline, total',
#     'amount': 17.9,
#     'unitName': 'MG'},
#    {'number': '430',
#     'name': 'Vitamin K (phylloquinone)',
#     'amount': 15.9,
#     'unitName': 'UG'},
#    {'number': '431', 'name': 'Folic acid', 'amount': 0.0, 'unitName': 'UG'},
#    {'number': '432', 'name': 'Folate, food', 'amount': 10.0, 'unitName': 'UG'},
#    {'number': '435', 'name': 'Folate, DFE', 'amount': 10.0, 'unitName': 'UG'},
#    {'number': '573',
#     'name': 'Vitamin E, added',
#     'amount': 0.0,
#     'unitName': 'MG'},
#    {'number': '578',
#     'name': 'Vitamin B-12, added',
#     'amount': 0.0,
#     'unitName': 'UG'},
#    {'number': '601', 'name': 'Cholesterol', 'amount': 10.0, 'unitName': 'MG'},
#    {'number': '606',
#     'name': 'Fatty acids, total saturated',
#     'amount': 0.627,
#     'unitName': 'G'},
#    {'number': '607', 'name': 'SFA 4:0', 'amount': 0.0, 'unitName': 'G'},
#    {'number': '608', 'name': 'SFA 6:0', 'amount': 0.0, 'unitName': 'G'},
#    {'number': '609', 'name': 'SFA 8:0', 'amount': 0.0, 'unitName': 'G'},
#    {'number': '610', 'name': 'SFA 10:0', 'amount': 0.001, 'unitName': 'G'},
#    {'number': '611', 'name': 'SFA 12:0', 'amount': 0.002, 'unitName': 'G'},
#    {'number': '612', 'name': 'SFA 14:0', 'amount': 0.023, 'unitName': 'G'},
#    {'number': '613', 'name': 'SFA 16:0', 'amount': 0.395, 'unitName': 'G'},
#    {'number': '614', 'name': 'SFA 18:0', 'amount': 0.193, 'unitName': 'G'},
#    {'number': '617', 'name': 'MUFA 18:1', 'amount': 0.822, 'unitName': 'G'},
#    {'number': '618', 'name': 'PUFA 18:2', 'amount': 0.355, 'unitName': 'G'},
#    {'number': '619', 'name': 'PUFA 18:3', 'amount': 0.038, 'unitName': 'G'},
#    {'number': '620', 'name': 'PUFA 20:4', 'amount': 0.005, 'unitName': 'G'},
#    {'number': '621',
#     'name': 'PUFA 22:6 n-3 (DHA)',
#     'amount': 0.0,
#     'unitName': 'G'},
#    {'number': '626', 'name': 'MUFA 16:1', 'amount': 0.049, 'unitName': 'G'},
#    {'number': '627', 'name': 'PUFA 18:4', 'amount': 0.0, 'unitName': 'G'},
#    {'number': '628', 'name': 'MUFA 20:1', 'amount': 0.015, 'unitName': 'G'},
#    {'number': '629',
#     'name': 'PUFA 20:5 n-3 (EPA)',
#     'amount': 0.0,
#     'unitName': 'G'},
#    {'number': '630', 'name': 'MUFA 22:1', 'amount': 0.0, 'unitName': 'G'},
#    {'number': '631',
#     'name': 'PUFA 22:5 n-3 (DPA)',
#     'amount': 0.0,
#     'unitName': 'G'},
#    {'number': '645',
#     'name': 'Fatty acids, total monounsaturated',
#     'amount': 0.892,
#     'unitName': 'G'},
#    {'number': '646',
#     'name': 'Fatty acids, total polyunsaturated',
#     'amount': 0.401,
#     'unitName': 'G'}]},
#  {'fdcId': 2341832,
#   'description': 'Pork with chili and tomatoes',
#   'dataType': 'Survey (FNDDS)',
#   'publicationDate': '2022-10-28',
#   'foodCode': '27121000',
#   'foodNutrients': [{'number': '203',
#     'name': 'Protein',
#     'amount': 11.6,
#     'unitName': 'G'},
#    {'number': '204',
#     'name': 'Total lipid (fat)',
#     'amount': 3.99,
#     'unitName': 'G'},
#    {'number': '205',
#     'name': 'Carbohydrate, by difference',
#     'amount': 2.68,
#     'unitName': 'G'},
#    {'number': '208', 'name': 'Energy', 'amount': 95.0, 'unitName': 'KCAL'},
#    {'number': '221', 'name': 'Alcohol, ethyl', 'amount': 0.0, 'unitName': 'G'},
#    {'number': '255', 'name': 'Water', 'amount': 80.8, 'unitName': 'G'},
#    {'number': '262', 'name': 'Caffeine', 'amount': 0.0, 'unitName': 'MG'},
#    {'number': '263', 'name': 'Theobromine', 'amount': 0.0, 'unitName': 'MG'},
#    {'number': '269',
#     'name': 'Sugars, total including NLEA',
#     'amount': 1.63,
#     'unitName': 'G'},
#    {'number': '291',
#     'name': 'Fiber, total dietary',
#     'amount': 0.9,
#     'unitName': 'G'},
#    {'number': '301', 'name': 'Calcium, Ca', 'amount': 15.0, 'unitName': 'MG'},
#    {'number': '303', 'name': 'Iron, Fe', 'amount': 0.58, 'unitName': 'MG'},
#    {'number': '304',
#     'name': 'Magnesium, Mg',
#     'amount': 18.0,
#     'unitName': 'MG'},
#    {'number': '305', 'name': 'Phosphorus, P', 'amount': 123, 'unitName': 'MG'},
#    {'number': '306', 'name': 'Potassium, K', 'amount': 323, 'unitName': 'MG'},
#    {'number': '307', 'name': 'Sodium, Na', 'amount': 118, 'unitName': 'MG'},
#    {'number': '309', 'name': 'Zinc, Zn', 'amount': 1.04, 'unitName': 'MG'},
#    {'number': '312', 'name': 'Copper, Cu', 'amount': 0.061, 'unitName': 'MG'},
#    {'number': '317', 'name': 'Selenium, Se', 'amount': 18.9, 'unitName': 'UG'},
#    {'number': '319', 'name': 'Retinol', 'amount': 1.0, 'unitName': 'UG'},
#    {'number': '320',
#     'name': 'Vitamin A, RAE',
#     'amount': 21.0,
#     'unitName': 'UG'},
#    {'number': '321',
#     'name': 'Carotene, beta',
#     'amount': 210,
#     'unitName': 'UG'},
#    {'number': '322',
#     'name': 'Carotene, alpha',
#     'amount': 41.0,
#     'unitName': 'UG'},
#    {'number': '323',
#     'name': 'Vitamin E (alpha-tocopherol)',
#     'amount': 0.7,
#     'unitName': 'MG'},
#    {'number': '328',
#     'name': 'Vitamin D (D2 + D3)',
#     'amount': 0.3,
#     'unitName': 'UG'},
#    {'number': '334',
#     'name': 'Cryptoxanthin, beta',
#     'amount': 11.0,
#     'unitName': 'UG'},
#    {'number': '337', 'name': 'Lycopene', 'amount': 849, 'unitName': 'UG'},
#    {'number': '338',
#     'name': 'Lutein + zeaxanthin',
#     'amount': 135,
#     'unitName': 'UG'},
#    {'number': '401',
#     'name': 'Vitamin C, total ascorbic acid',
#     'amount': 16.7,
#     'unitName': 'MG'},
#    {'number': '404', 'name': 'Thiamin', 'amount': 0.302, 'unitName': 'MG'},
#    {'number': '405', 'name': 'Riboflavin', 'amount': 0.141, 'unitName': 'MG'},
#    {'number': '406', 'name': 'Niacin', 'amount': 2.78, 'unitName': 'MG'},
#    {'number': '415', 'name': 'Vitamin B-6', 'amount': 0.255, 'unitName': 'MG'},
#    {'number': '417', 'name': 'Folate, total', 'amount': 9.0, 'unitName': 'UG'},
#    {'number': '418', 'name': 'Vitamin B-12', 'amount': 0.25, 'unitName': 'UG'},
#    {'number': '421',
#     'name': 'Choline, total',
#     'amount': 43.1,
#     'unitName': 'MG'},
#    {'number': '430',
#     'name': 'Vitamin K (phylloquinone)',
#     'amount': 5.0,
#     'unitName': 'UG'},
#    {'number': '431', 'name': 'Folic acid', 'amount': 0.0, 'unitName': 'UG'},
#    {'number': '432', 'name': 'Folate, food', 'amount': 9.0, 'unitName': 'UG'},
#    {'number': '435', 'name': 'Folate, DFE', 'amount': 9.0, 'unitName': 'UG'},
#    {'number': '573',
#     'name': 'Vitamin E, added',
#     'amount': 0.0,
#     'unitName': 'MG'},
#    {'number': '578',
#     'name': 'Vitamin B-12, added',
#     'amount': 0.0,
#     'unitName': 'UG'},
#    {'number': '601', 'name': 'Cholesterol', 'amount': 32.0, 'unitName': 'MG'},
#    {'number': '606',
#     'name': 'Fatty acids, total saturated',
#     'amount': 1.4,
#     'unitName': 'G'},
#    {'number': '607', 'name': 'SFA 4:0', 'amount': 0.0, 'unitName': 'G'},
#    {'number': '608', 'name': 'SFA 6:0', 'amount': 0.0, 'unitName': 'G'},
#    {'number': '609', 'name': 'SFA 8:0', 'amount': 0.0, 'unitName': 'G'},
#    {'number': '610', 'name': 'SFA 10:0', 'amount': 0.006, 'unitName': 'G'},
#    {'number': '611', 'name': 'SFA 12:0', 'amount': 0.007, 'unitName': 'G'},
#    {'number': '612', 'name': 'SFA 14:0', 'amount': 0.05, 'unitName': 'G'},
#    {'number': '613', 'name': 'SFA 16:0', 'amount': 0.885, 'unitName': 'G'},
#    {'number': '614', 'name': 'SFA 18:0', 'amount': 0.447, 'unitName': 'G'},
#    {'number': '617', 'name': 'MUFA 18:1', 'amount': 1.6, 'unitName': 'G'},
#    {'number': '618', 'name': 'PUFA 18:2', 'amount': 0.385, 'unitName': 'G'},
#    {'number': '619', 'name': 'PUFA 18:3', 'amount': 0.027, 'unitName': 'G'},
#    {'number': '620', 'name': 'PUFA 20:4', 'amount': 0.036, 'unitName': 'G'},
#    {'number': '621',
#     'name': 'PUFA 22:6 n-3 (DHA)',
#     'amount': 0.0,
#     'unitName': 'G'},
#    {'number': '626', 'name': 'MUFA 16:1', 'amount': 0.119, 'unitName': 'G'},
#    {'number': '627', 'name': 'PUFA 18:4', 'amount': 0.0, 'unitName': 'G'},
#    {'number': '628', 'name': 'MUFA 20:1', 'amount': 0.03, 'unitName': 'G'},
#    {'number': '629',
#     'name': 'PUFA 20:5 n-3 (EPA)',
#     'amount': 0.0,
#     'unitName': 'G'},
#    {'number': '630', 'name': 'MUFA 22:1', 'amount': 0.0, 'unitName': 'G'},
#    {'number': '631',
#     'name': 'PUFA 22:5 n-3 (DPA)',
#     'amount': 0.0,
#     'unitName': 'G'},
#    {'number': '645',
#     'name': 'Fatty acids, total monounsaturated',
#     'amount': 1.76,
#     'unitName': 'G'},
#    {'number': '646',
#     'name': 'Fatty acids, total polyunsaturated',
#     'amount': 0.464,
#     'unitName': 'G'}]},
#  {'fdcId': 2342580,
#   'description': 'Pork with vegetable excluding carrots, broccoli and/or dark-green leafy; soup, Asian Style',
#   'dataType': 'Survey (FNDDS)',
#   'publicationDate': '2022-10-28',
#   'foodCode': '28320300',
#   'foodNutrients': [{'number': '203',
#     'name': 'Protein',
#     'amount': 6.07,
#     'unitName': 'G'},
#    {'number': '204',
#     'name': 'Total lipid (fat)',
#     'amount': 2.48,
#     'unitName': 'G'},
#    {'number': '205',
#     'name': 'Carbohydrate, by difference',
#     'amount': 2.54,
#     'unitName': 'G'},
#    {'number': '208', 'name': 'Energy', 'amount': 57.0, 'unitName': 'KCAL'},
#    {'number': '221', 'name': 'Alcohol, ethyl', 'amount': 0.0, 'unitName': 'G'},
#    {'number': '255', 'name': 'Water', 'amount': 87.7, 'unitName': 'G'},
#    {'number': '262', 'name': 'Caffeine', 'amount': 0.0, 'unitName': 'MG'},
#    {'number': '263', 'name': 'Theobromine', 'amount': 0.0, 'unitName': 'MG'},
#    {'number': '269',
#     'name': 'Sugars, total including NLEA',
#     'amount': 1.07,
#     'unitName': 'G'},
#    {'number': '291',
#     'name': 'Fiber, total dietary',
#     'amount': 0.8,
#     'unitName': 'G'},
#    {'number': '301', 'name': 'Calcium, Ca', 'amount': 22.0, 'unitName': 'MG'},
#    {'number': '303', 'name': 'Iron, Fe', 'amount': 0.66, 'unitName': 'MG'},
#    {'number': '304',
#     'name': 'Magnesium, Mg',
#     'amount': 11.0,
#     'unitName': 'MG'},
#    {'number': '305',
#     'name': 'Phosphorus, P',
#     'amount': 53.0,
#     'unitName': 'MG'},
#    {'number': '306', 'name': 'Potassium, K', 'amount': 168, 'unitName': 'MG'},
#    {'number': '307', 'name': 'Sodium, Na', 'amount': 325, 'unitName': 'MG'},
#    {'number': '309', 'name': 'Zinc, Zn', 'amount': 0.52, 'unitName': 'MG'},
#    {'number': '312', 'name': 'Copper, Cu', 'amount': 0.031, 'unitName': 'MG'},
#    {'number': '317', 'name': 'Selenium, Se', 'amount': 8.3, 'unitName': 'UG'},
#    {'number': '319', 'name': 'Retinol', 'amount': 0.0, 'unitName': 'UG'},
#    {'number': '320',
#     'name': 'Vitamin A, RAE',
#     'amount': 8.0,
#     'unitName': 'UG'},
#    {'number': '321',
#     'name': 'Carotene, beta',
#     'amount': 87.0,
#     'unitName': 'UG'},
#    {'number': '322',
#     'name': 'Carotene, alpha',
#     'amount': 10.0,
#     'unitName': 'UG'},
#    {'number': '323',
#     'name': 'Vitamin E (alpha-tocopherol)',
#     'amount': 0.24,
#     'unitName': 'MG'},
#    {'number': '328',
#     'name': 'Vitamin D (D2 + D3)',
#     'amount': 0.1,
#     'unitName': 'UG'},
#    {'number': '334',
#     'name': 'Cryptoxanthin, beta',
#     'amount': 0.0,
#     'unitName': 'UG'},
#    {'number': '337', 'name': 'Lycopene', 'amount': 0.0, 'unitName': 'UG'},
#    {'number': '338',
#     'name': 'Lutein + zeaxanthin',
#     'amount': 107,
#     'unitName': 'UG'},
#    {'number': '401',
#     'name': 'Vitamin C, total ascorbic acid',
#     'amount': 7.4,
#     'unitName': 'MG'},
#    {'number': '404', 'name': 'Thiamin', 'amount': 0.123, 'unitName': 'MG'},
#    {'number': '405', 'name': 'Riboflavin', 'amount': 0.085, 'unitName': 'MG'},
#    {'number': '406', 'name': 'Niacin', 'amount': 1.48, 'unitName': 'MG'},
#    {'number': '415', 'name': 'Vitamin B-6', 'amount': 0.119, 'unitName': 'MG'},
#    {'number': '417',
#     'name': 'Folate, total',
#     'amount': 13.0,
#     'unitName': 'UG'},
#    {'number': '418', 'name': 'Vitamin B-12', 'amount': 0.14, 'unitName': 'UG'},
#    {'number': '421',
#     'name': 'Choline, total',
#     'amount': 22.3,
#     'unitName': 'MG'},
#    {'number': '430',
#     'name': 'Vitamin K (phylloquinone)',
#     'amount': 19.1,
#     'unitName': 'UG'},
#    {'number': '431', 'name': 'Folic acid', 'amount': 0.0, 'unitName': 'UG'},
#    {'number': '432', 'name': 'Folate, food', 'amount': 13.0, 'unitName': 'UG'},
#    {'number': '435', 'name': 'Folate, DFE', 'amount': 13.0, 'unitName': 'UG'},
#    {'number': '573',
#     'name': 'Vitamin E, added',
#     'amount': 0.0,
#     'unitName': 'MG'},
#    {'number': '578',
#     'name': 'Vitamin B-12, added',
#     'amount': 0.0,
#     'unitName': 'UG'},
#    {'number': '601', 'name': 'Cholesterol', 'amount': 12.0, 'unitName': 'MG'},
#    {'number': '606',
#     'name': 'Fatty acids, total saturated',
#     'amount': 0.738,
#     'unitName': 'G'},
#    {'number': '607', 'name': 'SFA 4:0', 'amount': 0.0, 'unitName': 'G'},
#    {'number': '608', 'name': 'SFA 6:0', 'amount': 0.0, 'unitName': 'G'},
#    {'number': '609', 'name': 'SFA 8:0', 'amount': 0.0, 'unitName': 'G'},
#    {'number': '610', 'name': 'SFA 10:0', 'amount': 0.002, 'unitName': 'G'},
#    {'number': '611', 'name': 'SFA 12:0', 'amount': 0.002, 'unitName': 'G'},
#    {'number': '612', 'name': 'SFA 14:0', 'amount': 0.027, 'unitName': 'G'},
#    {'number': '613', 'name': 'SFA 16:0', 'amount': 0.467, 'unitName': 'G'},
#    {'number': '614', 'name': 'SFA 18:0', 'amount': 0.225, 'unitName': 'G'},
#    {'number': '617', 'name': 'MUFA 18:1', 'amount': 0.973, 'unitName': 'G'},
#    {'number': '618', 'name': 'PUFA 18:2', 'amount': 0.42, 'unitName': 'G'},
#    {'number': '619', 'name': 'PUFA 18:3', 'amount': 0.044, 'unitName': 'G'},
#    {'number': '620', 'name': 'PUFA 20:4', 'amount': 0.006, 'unitName': 'G'},
#    {'number': '621',
#     'name': 'PUFA 22:6 n-3 (DHA)',
#     'amount': 0.0,
#     'unitName': 'G'},
#    {'number': '626', 'name': 'MUFA 16:1', 'amount': 0.057, 'unitName': 'G'},
#    {'number': '627', 'name': 'PUFA 18:4', 'amount': 0.0, 'unitName': 'G'},
#    {'number': '628', 'name': 'MUFA 20:1', 'amount': 0.018, 'unitName': 'G'},
#    {'number': '629',
#     'name': 'PUFA 20:5 n-3 (EPA)',
#     'amount': 0.0,
#     'unitName': 'G'},
#    {'number': '630', 'name': 'MUFA 22:1', 'amount': 0.0, 'unitName': 'G'},
#    {'number': '631',
#     'name': 'PUFA 22:5 n-3 (DPA)',
#     'amount': 0.0,
#     'unitName': 'G'},
#    {'number': '645',
#     'name': 'Fatty acids, total monounsaturated',
#     'amount': 1.06,
#     'unitName': 'G'},
#    {'number': '646',
#     'name': 'Fatty acids, total polyunsaturated',
#     'amount': 0.475,
#     'unitName': 'G'}]}]

# %%
def needAllFood():
    pageNum = 1
    foods=[]
    while True:
        url = 'https://api.nal.usda.gov/fdc/v1/foods/list?query=&api_key=u983gbYksVQ78GYn6mlvsMTLw0jcU0btxntKZSX0&pageSize=200&pageNumber=' + str(pageNum)
        req = requests.get(url)
        if not req.ok:
            break
        foods = foods + req.json()
        pageNum = pageNum + 1
        
    return foods

# %%
listOfFoods = needAllFood()

# %%
len(listOfFoods)
# Out:
# 10000

# %%
listOfFoods[-1]
# Out:
# {'fdcId': 169158,
#  'description': 'Pork, cured, ham, slice, bone-in, separable lean only, heated, pan-broil',
#  'dataType': 'SR Legacy',
#  'publicationDate': '2019-04-01',
#  'ndbNumber': '10899',
#  'foodNutrients': [{'number': '204',
#    'name': 'Total lipid (fat)',
#    'amount': 4.09,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '210',
#    'name': 'Sucrose',
#    'amount': 0.63,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '211',
#    'name': 'Glucose',
#    'amount': 0.11,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '214',
#    'name': 'Maltose',
#    'amount': 0.0,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '255',
#    'name': 'Water',
#    'amount': 65.3,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '262',
#    'name': 'Caffeine',
#    'amount': 0.0,
#    'unitName': 'MG',
#    'derivationCode': 'Z',
#    'derivationDescription': 'Assumed zero (Insignificant amount or not naturally occurring in a food, such as fiber in meat)'},
#   {'number': '263',
#    'name': 'Theobromine',
#    'amount': 0.0,
#    'unitName': 'MG',
#    'derivationCode': 'Z',
#    'derivationDescription': 'Assumed zero (Insignificant amount or not naturally occurring in a food, such as fiber in meat)'},
#   {'number': '269',
#    'name': 'Sugars, total including NLEA',
#    'amount': 0.74,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '301',
#    'name': 'Calcium, Ca',
#    'amount': 15.0,
#    'unitName': 'MG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '306',
#    'name': 'Potassium, K',
#    'amount': 427,
#    'unitName': 'MG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '309',
#    'name': 'Zinc, Zn',
#    'amount': 3.04,
#    'unitName': 'MG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '317',
#    'name': 'Selenium, Se',
#    'amount': 25.3,
#    'unitName': 'UG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '323',
#    'name': 'Vitamin E (alpha-tocopherol)',
#    'amount': 0.3,
#    'unitName': 'MG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '454',
#    'name': 'Betaine',
#    'amount': 7.3,
#    'unitName': 'MG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '503',
#    'name': 'Isoleucine',
#    'amount': 1.23,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '504',
#    'name': 'Leucine',
#    'amount': 2.18,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '505',
#    'name': 'Lysine',
#    'amount': 2.3,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '507',
#    'name': 'Cystine',
#    'amount': 0.305,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '510',
#    'name': 'Valine',
#    'amount': 1.38,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '511',
#    'name': 'Arginine',
#    'amount': 1.74,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '512',
#    'name': 'Histidine',
#    'amount': 1.18,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '514',
#    'name': 'Aspartic acid',
#    'amount': 2.37,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '518',
#    'name': 'Serine',
#    'amount': 1.06,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '573',
#    'name': 'Vitamin E, added',
#    'amount': 0.0,
#    'unitName': 'MG',
#    'derivationCode': 'Z',
#    'derivationDescription': 'Assumed zero (Insignificant amount or not naturally occurring in a food, such as fiber in meat)'},
#   {'number': '607',
#    'name': 'SFA 4:0',
#    'amount': 0.0,
#    'unitName': 'G',
#    'derivationCode': 'Z',
#    'derivationDescription': 'Assumed zero (Insignificant amount or not naturally occurring in a food, such as fiber in meat)'},
#   {'number': '608',
#    'name': 'SFA 6:0',
#    'amount': 0.0,
#    'unitName': 'G',
#    'derivationCode': 'Z',
#    'derivationDescription': 'Assumed zero (Insignificant amount or not naturally occurring in a food, such as fiber in meat)'},
#   {'number': '610',
#    'name': 'SFA 10:0',
#    'amount': 0.0,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '613',
#    'name': 'SFA 16:0',
#    'amount': 0.778,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '614',
#    'name': 'SFA 18:0',
#    'amount': 0.415,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '615',
#    'name': 'SFA 20:0',
#    'amount': 0.005,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '338',
#    'name': 'Lutein + zeaxanthin',
#    'amount': 0.0,
#    'unitName': 'UG',
#    'derivationCode': 'Z',
#    'derivationDescription': 'Assumed zero (Insignificant amount or not naturally occurring in a food, such as fiber in meat)'},
#   {'number': '341',
#    'name': 'Tocopherol, beta',
#    'amount': 0.0,
#    'unitName': 'MG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '342',
#    'name': 'Tocopherol, gamma',
#    'amount': 0.03,
#    'unitName': 'MG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '344',
#    'name': 'Tocotrienol, alpha',
#    'amount': 0.0,
#    'unitName': 'MG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '345',
#    'name': 'Tocotrienol, beta',
#    'amount': 0.0,
#    'unitName': 'MG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '406',
#    'name': 'Niacin',
#    'amount': 7.77,
#    'unitName': 'MG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '410',
#    'name': 'Pantothenic acid',
#    'amount': 0.758,
#    'unitName': 'MG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '415',
#    'name': 'Vitamin B-6',
#    'amount': 0.54,
#    'unitName': 'MG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '421', 'name': 'Choline, total', 'amount': 113, 'unitName': 'MG'},
#   {'number': '428',
#    'name': 'Vitamin K (Menaquinone-4)',
#    'amount': 2.0,
#    'unitName': 'UG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '431',
#    'name': 'Folic acid',
#    'amount': 0.0,
#    'unitName': 'UG',
#    'derivationCode': 'Z',
#    'derivationDescription': 'Assumed zero (Insignificant amount or not naturally occurring in a food, such as fiber in meat)'},
#   {'number': '620',
#    'name': 'PUFA 20:4',
#    'amount': 0.084,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '627',
#    'name': 'PUFA 18:4',
#    'amount': 0.0,
#    'unitName': 'G',
#    'derivationCode': 'Z',
#    'derivationDescription': 'Assumed zero (Insignificant amount or not naturally occurring in a food, such as fiber in meat)'},
#   {'number': '628',
#    'name': 'MUFA 20:1',
#    'amount': 0.021,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '630',
#    'name': 'MUFA 22:1',
#    'amount': 0.0,
#    'unitName': 'G',
#    'derivationCode': 'Z',
#    'derivationDescription': 'Assumed zero (Insignificant amount or not naturally occurring in a food, such as fiber in meat)'},
#   {'number': '652',
#    'name': 'SFA 15:0',
#    'amount': 0.0,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '663',
#    'name': 'TFA 18:1 t',
#    'amount': 0.017,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '669',
#    'name': 'TFA 18:2 t,t',
#    'amount': 0.013,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '672',
#    'name': 'PUFA 20:2 n-6 c,c',
#    'amount': 0.016,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '685',
#    'name': 'PUFA 18:3 n-6 c,c,c',
#    'amount': 0.0,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '689',
#    'name': 'PUFA 20:3',
#    'amount': 0.003,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '203',
#    'name': 'Protein',
#    'amount': 27.2,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '207',
#    'name': 'Ash',
#    'amount': 3.17,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '212',
#    'name': 'Fructose',
#    'amount': 0.0,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '213',
#    'name': 'Lactose',
#    'amount': 0.0,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '221',
#    'name': 'Alcohol, ethyl',
#    'amount': 0.0,
#    'unitName': 'G',
#    'derivationCode': 'Z',
#    'derivationDescription': 'Assumed zero (Insignificant amount or not naturally occurring in a food, such as fiber in meat)'},
#   {'number': '287',
#    'name': 'Galactose',
#    'amount': 0.0,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '291',
#    'name': 'Fiber, total dietary',
#    'amount': 0.0,
#    'unitName': 'G',
#    'derivationCode': 'Z',
#    'derivationDescription': 'Assumed zero (Insignificant amount or not naturally occurring in a food, such as fiber in meat)'},
#   {'number': '303',
#    'name': 'Iron, Fe',
#    'amount': 1.42,
#    'unitName': 'MG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '304',
#    'name': 'Magnesium, Mg',
#    'amount': 25.0,
#    'unitName': 'MG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '305',
#    'name': 'Phosphorus, P',
#    'amount': 296,
#    'unitName': 'MG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '307',
#    'name': 'Sodium, Na',
#    'amount': 870,
#    'unitName': 'MG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '312',
#    'name': 'Copper, Cu',
#    'amount': 0.426,
#    'unitName': 'MG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '315',
#    'name': 'Manganese, Mn',
#    'amount': 0.022,
#    'unitName': 'MG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '318', 'name': 'Vitamin A, IU', 'amount': 0.0, 'unitName': 'IU'},
#   {'number': '319',
#    'name': 'Retinol',
#    'amount': 0.0,
#    'unitName': 'UG',
#    'derivationCode': 'NR',
#    'derivationDescription': 'Nutrient that is based on other nutrient/s; value used directly, ex. Nut.#204 from Nut.#298'},
#   {'number': '320', 'name': 'Vitamin A, RAE', 'amount': 0.0, 'unitName': 'UG'},
#   {'number': '321',
#    'name': 'Carotene, beta',
#    'amount': 0.0,
#    'unitName': 'UG',
#    'derivationCode': 'Z',
#    'derivationDescription': 'Assumed zero (Insignificant amount or not naturally occurring in a food, such as fiber in meat)'},
#   {'number': '322',
#    'name': 'Carotene, alpha',
#    'amount': 0.0,
#    'unitName': 'UG',
#    'derivationCode': 'Z',
#    'derivationDescription': 'Assumed zero (Insignificant amount or not naturally occurring in a food, such as fiber in meat)'},
#   {'number': '334',
#    'name': 'Cryptoxanthin, beta',
#    'amount': 0.0,
#    'unitName': 'UG',
#    'derivationCode': 'Z',
#    'derivationDescription': 'Assumed zero (Insignificant amount or not naturally occurring in a food, such as fiber in meat)'},
#   {'number': '337',
#    'name': 'Lycopene',
#    'amount': 0.0,
#    'unitName': 'UG',
#    'derivationCode': 'Z',
#    'derivationDescription': 'Assumed zero (Insignificant amount or not naturally occurring in a food, such as fiber in meat)'},
#   {'number': '343',
#    'name': 'Tocopherol, delta',
#    'amount': 0.0,
#    'unitName': 'MG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '346',
#    'name': 'Tocotrienol, gamma',
#    'amount': 0.02,
#    'unitName': 'MG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '347',
#    'name': 'Tocotrienol, delta',
#    'amount': 0.0,
#    'unitName': 'MG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '401',
#    'name': 'Vitamin C, total ascorbic acid',
#    'amount': 0.0,
#    'unitName': 'MG',
#    'derivationCode': 'Z',
#    'derivationDescription': 'Assumed zero (Insignificant amount or not naturally occurring in a food, such as fiber in meat)'},
#   {'number': '404',
#    'name': 'Thiamin',
#    'amount': 0.575,
#    'unitName': 'MG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '405',
#    'name': 'Riboflavin',
#    'amount': 0.317,
#    'unitName': 'MG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '417',
#    'name': 'Folate, total',
#    'amount': 2.0,
#    'unitName': 'UG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '418',
#    'name': 'Vitamin B-12',
#    'amount': 0.66,
#    'unitName': 'UG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '429',
#    'name': 'Vitamin K (Dihydrophylloquinone)',
#    'amount': 0.0,
#    'unitName': 'UG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '430',
#    'name': 'Vitamin K (phylloquinone)',
#    'amount': 0.0,
#    'unitName': 'UG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '432',
#    'name': 'Folate, food',
#    'amount': 2.0,
#    'unitName': 'UG',
#    'derivationCode': 'NR',
#    'derivationDescription': 'Nutrient that is based on other nutrient/s; value used directly, ex. Nut.#204 from Nut.#298'},
#   {'number': '501',
#    'name': 'Tryptophan',
#    'amount': 0.255,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '502',
#    'name': 'Threonine',
#    'amount': 1.22,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '506',
#    'name': 'Methionine',
#    'amount': 0.65,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '508',
#    'name': 'Phenylalanine',
#    'amount': 1.09,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '509',
#    'name': 'Tyrosine',
#    'amount': 0.882,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '513',
#    'name': 'Alanine',
#    'amount': 1.6,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '515',
#    'name': 'Glutamic acid',
#    'amount': 3.89,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '516',
#    'name': 'Glycine',
#    'amount': 1.42,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '517',
#    'name': 'Proline',
#    'amount': 1.17,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '578',
#    'name': 'Vitamin B-12, added',
#    'amount': 0.0,
#    'unitName': 'UG',
#    'derivationCode': 'Z',
#    'derivationDescription': 'Assumed zero (Insignificant amount or not naturally occurring in a food, such as fiber in meat)'},
#   {'number': '601',
#    'name': 'Cholesterol',
#    'amount': 73.0,
#    'unitName': 'MG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '609',
#    'name': 'SFA 8:0',
#    'amount': 0.0,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '611',
#    'name': 'SFA 12:0',
#    'amount': 0.0,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '612',
#    'name': 'SFA 14:0',
#    'amount': 0.045,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '621',
#    'name': 'PUFA 22:6 n-3 (DHA)',
#    'amount': 0.0,
#    'unitName': 'G',
#    'derivationCode': 'Z',
#    'derivationDescription': 'Assumed zero (Insignificant amount or not naturally occurring in a food, such as fiber in meat)'},
#   {'number': '624',
#    'name': 'SFA 22:0',
#    'amount': 0.0,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '625',
#    'name': 'MUFA 14:1',
#    'amount': 0.0,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '626',
#    'name': 'MUFA 16:1',
#    'amount': 0.099,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '629',
#    'name': 'PUFA 20:5 n-3 (EPA)',
#    'amount': 0.0,
#    'unitName': 'G',
#    'derivationCode': 'Z',
#    'derivationDescription': 'Assumed zero (Insignificant amount or not naturally occurring in a food, such as fiber in meat)'},
#   {'number': '631',
#    'name': 'PUFA 22:5 n-3 (DPA)',
#    'amount': 0.0,
#    'unitName': 'G',
#    'derivationCode': 'Z',
#    'derivationDescription': 'Assumed zero (Insignificant amount or not naturally occurring in a food, such as fiber in meat)'},
#   {'number': '653',
#    'name': 'SFA 17:0',
#    'amount': 0.011,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '674',
#    'name': 'MUFA 18:1 c',
#    'amount': 1.48,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '675',
#    'name': 'PUFA 18:2 n-6 c,c',
#    'amount': 0.499,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '687',
#    'name': 'MUFA 17:1',
#    'amount': 0.0,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '697',
#    'name': 'MUFA 15:1',
#    'amount': 0.0,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '851',
#    'name': 'PUFA 18:3 n-3 c,c,c (ALA)',
#    'amount': 0.029,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '324',
#    'name': 'Vitamin D (D2 + D3), International Units',
#    'amount': 44.0,
#    'unitName': 'IU',
#    'derivationCode': 'BFNN',
#    'derivationDescription': 'Based on another form of the food or similar food; Concentration adjustment; Non-fat solids; Retention factors not used'},
#   {'number': '326',
#    'name': 'Vitamin D3 (cholecalciferol)',
#    'amount': 1.1,
#    'unitName': 'UG',
#    'derivationCode': 'BFNN',
#    'derivationDescription': 'Based on another form of the food or similar food; Concentration adjustment; Non-fat solids; Retention factors not used'},
#   {'number': '328',
#    'name': 'Vitamin D (D2 + D3)',
#    'amount': 1.1,
#    'unitName': 'UG'},
#   {'number': '521',
#    'name': 'Hydroxyproline',
#    'amount': 0.176,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '695',
#    'name': 'Fatty acids, total trans-polyenoic',
#    'amount': 0.013,
#    'unitName': 'G',
#    'derivationCode': 'NC',
#    'derivationDescription': 'Calculated'},
#   {'number': '645',
#    'name': 'Fatty acids, total monounsaturated',
#    'amount': 1.61,
#    'unitName': 'G',
#    'derivationCode': 'NC',
#    'derivationDescription': 'Calculated'},
#   {'number': '646',
#    'name': 'Fatty acids, total polyunsaturated',
#    'amount': 0.644,
#    'unitName': 'G',
#    'derivationCode': 'NC',
#    'derivationDescription': 'Calculated'},
#   {'number': '435',
#    'name': 'Folate, DFE',
#    'amount': 2.0,
#    'unitName': 'UG',
#    'derivationCode': 'NC',
#    'derivationDescription': 'Calculated'},
#   {'number': '617', 'name': 'MUFA 18:1', 'amount': 1.49, 'unitName': 'G'},
#   {'number': '618', 'name': 'PUFA 18:2', 'amount': 0.512, 'unitName': 'G'},
#   {'number': '619', 'name': 'PUFA 18:3', 'amount': 0.029, 'unitName': 'G'},
#   {'number': '693',
#    'name': 'Fatty acids, total trans-monoenoic',
#    'amount': 0.017,
#    'unitName': 'G',
#    'derivationCode': 'NC',
#    'derivationDescription': 'Calculated'},
#   {'number': '605',
#    'name': 'Fatty acids, total trans',
#    'amount': 0.03,
#    'unitName': 'G',
#    'derivationCode': 'NC',
#    'derivationDescription': 'Calculated'},
#   {'number': '606',
#    'name': 'Fatty acids, total saturated',
#    'amount': 1.25,
#    'unitName': 'G',
#    'derivationCode': 'NC',
#    'derivationDescription': 'Calculated'},
#   {'number': '205',
#    'name': 'Carbohydrate, by difference',
#    'amount': 0.74,
#    'unitName': 'G',
#    'derivationCode': 'NR',
#    'derivationDescription': 'Nutrient that is based on other nutrient/s; value used directly, ex. Nut.#204 from Nut.#298'},
#   {'number': '208',
#    'name': 'Energy',
#    'amount': 148,
#    'unitName': 'KCAL',
#    'derivationCode': 'NC',
#    'derivationDescription': 'Calculated'},
#   {'number': '268',
#    'name': 'Energy',
#    'amount': 621,
#    'unitName': 'kJ',
#    'derivationCode': 'NC',
#    'derivationDescription': 'Calculated'}]}

# %%
def getIron():
    iron = []
    for food in listOfFoods:
        name = food['description']
        for nutrient in food['foodNutrients']:
            if nutrient['name'] == 'Iron, Fe':
                amount = nutrient['amount']
                temp = {'Name': name, 'Iron': amount}
                iron.append(temp)
    return iron

# %%
data = getIron()
print(data)
# Out:
# [{'Name': 'Abalone', 'Iron': 3.97}, {'Name': 'Abiyuch, raw', 'Iron': 1.61}, {'Name': 'Acerola juice, raw', 'Iron': 0.5}, {'Name': 'Acerola, (west indian cherry), raw', 'Iron': 0.2}, {'Name': 'Acorn stew (Apache)', 'Iron': 1.0}, {'Name': 'Adobo, with noodles', 'Iron': 0.99}, {'Name': 'Adobo, with rice', 'Iron': 1.34}, {'Name': 'Agave liquid sweetener', 'Iron': 0.09}, {'Name': 'Agave, cooked (Southwest)', 'Iron': 3.55}, {'Name': 'Agave, dried (Southwest)', 'Iron': 3.64}, {'Name': 'Agave, raw (Southwest)', 'Iron': 1.8}, {'Name': 'Agutuk, fish with shortening (Alaskan ice cream) (Alaska Native)', 'Iron': 0.2}, {'Name': 'Agutuk, fish/berry with seal oil (Alaskan ice cream) (Alaska Native)', 'Iron': 0.3}, {'Name': 'Agutuk, meat-caribou (Alaskan ice cream) (Alaska Native)', 'Iron': 4.55}, {'Name': 'Alcoholic beverage, beer, light', 'Iron': 0.03}, {'Name': 'Alcoholic beverage, beer, light, BUD LIGHT', 'Iron': 0.0}, {'Name': 'Alcoholic beverage, beer, light, BUDWEISER SELECT', 'Iron': 0.0}, {'Name': 'Alcoholic beverage, beer, light, higher alcohol', 'Iron': 0.03}, {'Name': 'Alcoholic beverage, beer, light, low carb', 'Iron': 0.0}, {'Name': 'Alcoholic beverage, beer, regular, all', 'Iron': 0.02}, {'Name': 'Alcoholic beverage, beer, regular, BUDWEISER', 'Iron': 0.0}, {'Name': 'Alcoholic beverage, creme de menthe, 72 proof', 'Iron': 0.07}, {'Name': 'Alcoholic beverage, daiquiri, canned', 'Iron': 0.01}, {'Name': 'Alcoholic beverage, daiquiri, prepared-from-recipe', 'Iron': 0.09}, {'Name': 'Alcoholic beverage, distilled, all (gin, rum, vodka, whiskey) 100 proof', 'Iron': 0.04}, {'Name': 'Alcoholic beverage, distilled, all (gin, rum, vodka, whiskey) 80 proof', 'Iron': 0.04}, {'Name': 'Alcoholic beverage, distilled, all (gin, rum, vodka, whiskey) 86 proof', 'Iron': 0.04}, {'Name': 'Alcoholic beverage, distilled, all (gin, rum, vodka, whiskey) 90 proof', 'Iron': 0.04}, {'Name': 'Alcoholic beverage, distilled, all (gin, rum, vodka, whiskey) 94 proof', 'Iron': 0.04}, {'Name': 'Alcoholic beverage, distilled, rum, 80 proof', 'Iron': 0.12}, {'Name': 'Alcoholic beverage, distilled, vodka, 80 proof', 'Iron': 0.01}, {'Name': 'Alcoholic beverage, distilled, whiskey, 86 proof', 'Iron': 0.02}, {'Name': 'Alcoholic beverage, liqueur, coffee with cream, 34 proof', 'Iron': 0.13}, {'Name': 'Alcoholic beverage, liqueur, coffee, 53 proof', 'Iron': 0.06}, {'Name': 'Alcoholic beverage, liqueur, coffee, 63 proof', 'Iron': 0.06}, {'Name': 'Alcoholic beverage, malt beer, hard lemonade', 'Iron': 0.03}, {'Name': 'Alcoholic beverage, pina colada, canned', 'Iron': 0.03}, {'Name': 'Alcoholic beverage, pina colada, prepared-from-recipe', 'Iron': 0.21}, {'Name': 'Alcoholic beverage, rice (sake)', 'Iron': 0.1}, {'Name': 'Alcoholic beverage, tequila sunrise, canned', 'Iron': 0.02}, {'Name': 'Alcoholic beverage, whiskey sour', 'Iron': 0.08}, {'Name': 'Alcoholic beverage, whiskey sour, canned', 'Iron': 0.01}, {'Name': 'Alcoholic beverage, whiskey sour, prepared from item 14028', 'Iron': 0.08}, {'Name': 'Alcoholic beverage, whiskey sour, prepared with water, whiskey and powder mix', 'Iron': 0.08}, {'Name': 'Alcoholic beverage, wine, cooking', 'Iron': 0.4}, {'Name': 'Alcoholic beverage, wine, dessert, dry', 'Iron': 0.24}, {'Name': 'Alcoholic beverage, wine, dessert, sweet', 'Iron': 0.24}, {'Name': 'Alcoholic beverage, wine, light', 'Iron': 0.4}, {'Name': 'Alcoholic beverage, wine, table, all', 'Iron': 0.37}, {'Name': 'Alcoholic beverage, wine, table, red', 'Iron': 0.46}, {'Name': 'Alcoholic Beverage, wine, table, red, Merlot', 'Iron': 0.46}, {'Name': 'Alcoholic beverage, wine, table, white', 'Iron': 0.27}, {'Name': 'Alcoholic beverage, wine, table, white, Chardonnay', 'Iron': 0.27}, {'Name': 'Alcoholic beverages, beer, higher alcohol', 'Iron': 0.03}, {'Name': 'Alcoholic beverages, wine, rose', 'Iron': 0.2}, {'Name': 'Alcoholic malt beverage', 'Iron': 0.03}, {'Name': 'Alcoholic malt beverage, sweetened', 'Iron': 0.03}, {'Name': 'Alexander', 'Iron': 0.05}, {'Name': 'Alfalfa seeds, ...

# %%
df = pd.DataFrame(data)
df.sort_values(by='Iron', ascending=False, inplace = True)

# %%
top10 = df.head(10)
df = df[df["Name"].str.contains("baby")==False]
df = df[df["Name"].str.contains("Baby")==False]
df
# Out:
#                                                    Name  Iron
# 3367  Cereals ready-to-eat, RALSTON Enriched Wheat B...  67.7
# 8976                              Parsley, freeze-dried  53.9
# 3451         Cereals, QUAKER, Quick Oats with Iron, Dry  49.4
# 3248                            Cereal, O's, multigrain  46.6
# 1961   Beef, variety meats and by-products, spleen, raw  44.6
# ...                                                 ...   ...
# 2230  Beverages, The COCA-COLA company, Hi-C Flashin...   0.0
# 6464         Fruit juice drink, reduced sugar (Sunny D)   0.0
# 2256                   Beverages, water, tap, municipal   0.0
# 2231  Beverages, The COCA-COLA company, Minute Maid,...   0.0
# 9311                                     Pectin, liquid   0.0
#
# [9559 rows x 2 columns]

# %%
sb.barplot(x=top10["Iron"], y=top10["Name"])
# Out:
# <AxesSubplot:xlabel='Iron', ylabel='Name'>

# %%
sb.histplot(df['Iron'])
# Out:
# <AxesSubplot:xlabel='Iron', ylabel='Count'>

# %%
df['Iron'].quantile
# Out:
# <bound method Series.quantile of 3367    67.7
# 8976    53.9
# 3451    49.4
# 3248    46.6
# 1961    44.6
#         ...
# 2230     0.0
# 6464     0.0
# 2256     0.0
# 2231     0.0
# 9311     0.0
# Name: Iron, Length: 9559, dtype: float64>
