# %%
import pandas as pd
import seaborn as sbn
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('MusicData.csv')
df
# Out:
#                                                  title            artist  \
# 0                                     Hey, Soul Sister             Train
# 1                                 Love The Way You Lie            Eminem
# 2                                              TiK ToK             Kesha
# 3                                          Bad Romance         Lady Gaga
# 4                                 Just the Way You Are        Bruno Mars
# ..                                                 ...               ...
# 598                Find U Again (feat. Camila Cabello)       Mark Ronson
# 599      Cross Me (feat. Chance the Rapper & PnB Rock)        Ed Sheeran
# 600  No Brainer (feat. Justin Bieber, Chance the Ra...         DJ Khaled
# 601    Nothing Breaks Like a Heart (feat. Miley Cyrus)       Mark Ronson
# 602                                   Kills You Slowly  The Chainsmokers
#
#     the genre of the track  year  Beats.Per.Minute -The tempo of the song  \
# 0               neo mellow  2010                                       97
# 1          detroit hip hop  2010                                       87
# 2                dance pop  2010                                      120
# 3                dance pop  2010                                      119
# 4                      pop  2010                                      109
# ..                     ...   ...                                      ...
# 598              dance pop  2019                                      104
# 599                    pop  2019                                       95
# 600              dance pop  2019                                      136
# 601              dance pop  2019                                      114
# 602             electropop  2019                                      150
#
#      Energy- The energy of a song - the higher the value, the more energtic  \
# 0                                                   89
# 1                                                   93
# 2                                                   84
# 3                                                   92
# 4                                                   84
# ..                                                 ...
# 598                                                 66
# 599                                                 79
# 600                                                 76
# 601                                                 79
# 602                                                 44
#
#      Danceability - The higher the value, the easier it is to dance to this song  \
# 0                                                   67
# 1                                                   75
# 2                                                   76
# 3                                                   70
# 4                                                   64
# ..                                                 ...
# 598                                                 61
# 599                                                 75
# 600                                                 53
# 601                                                 60
# 602                                                 70
#
#      Loudness/dB - The higher the value, the louder the song  \
# 0                                                   -4
# 1                                                   -5
# 2                                                   -3
# 3                                                   -4
# 4                                                   -5
# ..                                                 ...
# 598                                                 -7
# 599                                                 -6
# 600                                                 -5
# 601                                                 -6
# 602                                                 -9
#
#      Liveness - The higher the value, the more likely the song is a live recording  \
# 0                                                    8
# 1                                                   52
# 2                                                   29
# 3                                                    8
# 4                                                    9
# ..                                                 ...
# 598                                                 20
# 599                                                  7
# 600                                                  9
# 601                                                 42
# 602                                                 13
#
#      Valence - The higher the value, the more positive mood for the song  \
# 0                                                   80
# 1                                                   64
# 2                                                   71
# 3                                                   71
# 4                                                   43
# ..                                                 ...
# 598                                                 16
# 599                                                 61
# 600                                                 65
# 601                                                 24
# 602                                                 23
#
#      Length - The duration of the song  \
# 0                                  217
# 1                                  263
# 2                                  200
# 3                                  295
# 4                                  221
# ..                                 ...
# 598                                176
# 599                                206
# 600                                260
# 601                                217
# 602                                213
#
#      Acousticness - The higher the value the more acoustic the song is  \
# 0                                                   19
# 1                                                   24
# 2                                                   10
# 3                                                    0
# 4                                                    2
# ..                                                 ...
# 598                                                  1
# 599                                                 21
# 600                                                  7
# 601                                                  1
# 602                                                  6
#
#      Speechiness - The higher the value the more spoken word the song contains  \
# 0                                                    4
# 1                                                   23
# 2                                                   14
# 3                                                    4
# 4                                                    4
# ..                                                 ...
# 598                                                  3
# 599                                                 12
# 600                                                 34
# 601                                                  7
# 602                                                  6
#
#      Popularity- The higher the value the more popular the song is
# 0                                                   83
# 1                                                   82
# 2                                                   80
# 3                                                   79
# 4                                                   78
# ..                                                 ...
# 598                                                 75
# 599                                                 75
# 600                                                 70
# 601                                                 69
# 602                                                 67
#
# [603 rows x 14 columns]

# %%
df.isnull().values.any()
df.dropna(inplace = True)
df.isnull().values.any()
# Out:
# False

# %%
df.rename(columns={"Energy- The energy of a song - the higher the value, the more energtic":'energy','the genre of the track':'genre','Beats.Per.Minute -The tempo of the song':'bpm','Danceability - The higher the value, the easier it is to dance to this song':'danceability','Loudness/dB - The higher the value, the louder the song':'loudness','Liveness - The higher the value, the more likely the song is a live recording':'live recording','Valence - The higher the value, the more positive mood for the song':'positivity','Length - The duration of the song':'track length','Acousticness - The higher the value the more acoustic the song is':'acousticness','Speechiness - The higher the value the more spoken word the song contains':'spoken word',"Popularity- The higher the value the more popular the song is":'popularity'}, inplace = True)
df
# Out:
#                                                  title            artist  \
# 0                                     Hey, Soul Sister             Train
# 1                                 Love The Way You Lie            Eminem
# 2                                              TiK ToK             Kesha
# 3                                          Bad Romance         Lady Gaga
# 4                                 Just the Way You Are        Bruno Mars
# ..                                                 ...               ...
# 598                Find U Again (feat. Camila Cabello)       Mark Ronson
# 599      Cross Me (feat. Chance the Rapper & PnB Rock)        Ed Sheeran
# 600  No Brainer (feat. Justin Bieber, Chance the Ra...         DJ Khaled
# 601    Nothing Breaks Like a Heart (feat. Miley Cyrus)       Mark Ronson
# 602                                   Kills You Slowly  The Chainsmokers
#
#                genre  year  bpm  energy  danceability  loudness  \
# 0         neo mellow  2010   97      89            67        -4
# 1    detroit hip hop  2010   87      93            75        -5
# 2          dance pop  2010  120      84            76        -3
# 3          dance pop  2010  119      92            70        -4
# 4                pop  2010  109      84            64        -5
# ..               ...   ...  ...     ...           ...       ...
# 598        dance pop  2019  104      66            61        -7
# 599              pop  2019   95      79            75        -6
# 600        dance pop  2019  136      76            53        -5
# 601        dance pop  2019  114      79            60        -6
# 602       electropop  2019  150      44            70        -9
#
#      live recording  positivity  track length  acousticness  spoken word  \
# 0                 8          80           217            19            4
# 1                52          64           263            24           23
# 2                29          71           200            10           14
# 3                 8          71           295             0            4
# 4                 9          43           221             2            4
# ..              ...         ...           ...           ...          ...
# 598              20          16           176             1            3
# 599               7          61           206            21           12
# 600               9          65           260             7           34
# 601              42          24           217             1            7
# 602              13          23           213             6            6
#
#      popularity
# 0            83
# 1            82
# 2            80
# 3            79
# 4            78
# ..          ...
# 598          75
# 599          75
# 600          70
# 601          69
# 602          67
#
# [603 rows x 14 columns]

# %%
df.drop(['energy','danceability','live recording','positivity','acousticness','spoken word'], axis = 1, inplace = True)
df
# Out:
#                                                  title            artist  \
# 0                                     Hey, Soul Sister             Train
# 1                                 Love The Way You Lie            Eminem
# 2                                              TiK ToK             Kesha
# 3                                          Bad Romance         Lady Gaga
# 4                                 Just the Way You Are        Bruno Mars
# ..                                                 ...               ...
# 598                Find U Again (feat. Camila Cabello)       Mark Ronson
# 599      Cross Me (feat. Chance the Rapper & PnB Rock)        Ed Sheeran
# 600  No Brainer (feat. Justin Bieber, Chance the Ra...         DJ Khaled
# 601    Nothing Breaks Like a Heart (feat. Miley Cyrus)       Mark Ronson
# 602                                   Kills You Slowly  The Chainsmokers
#
#                genre  year  bpm  loudness  track length  popularity
# 0         neo mellow  2010   97        -4           217          83
# 1    detroit hip hop  2010   87        -5           263          82
# 2          dance pop  2010  120        -3           200          80
# 3          dance pop  2010  119        -4           295          79
# 4                pop  2010  109        -5           221          78
# ..               ...   ...  ...       ...           ...         ...
# 598        dance pop  2019  104        -7           176          75
# 599              pop  2019   95        -6           206          75
# 600        dance pop  2019  136        -5           260          70
# 601        dance pop  2019  114        -6           217          69
# 602       electropop  2019  150        -9           213          67
#
# [603 rows x 8 columns]

# %%
df.sort_values('popularity',ascending = True,inplace = True)
df.head(10)
# Out:
#                              title             artist           genre  year  \
# 267                Not a Bad Thing  Justin Timberlake       dance pop  2014
# 50                           Hello     Martin Solveig        big room  2010
# 138        Blow Me (One Last Kiss)               P!nk       dance pop  2012
# 442              Million Years Ago              Adele    british soul  2016
# 362               L.A.LOVE (la la)             Fergie       dance pop  2015
# 103  Muny - Album Version (Edited)        Nicki Minaj       dance pop  2011
# 361                      Dangerous    Jennifer Hudson       dance pop  2015
# 441               Behind Your Back      Nelly Furtado  canadian latin  2016
# 102                       Firework         Katy Perry       dance pop  2011
# 101   Last Friday Night (T.G.I.F.)         Katy Perry       dance pop  2011
#
#      bpm  loudness  track length  popularity
# 267   86        -6           266           0
# 50   128        -3           191           0
# 138  114        -3           256           0
# 442    0       -60           227           0
# 362  202        -8           193           0
# 103   98        -5           227           7
# 361  109        -5           255          18
# 441   98       -10           228          18
# 102  124        -5           228          25
# 101  126        -4           231          27

# %%
#df = df[df["genre"].str.contains("pop")==True]
df.head(10)
# Out:
#                                                  title         artist  \
# 572                                           Memories       Maroon 5
# 573                                Lose You To Love Me   Selena Gomez
# 574                                  Someone You Loved  Lewis Capaldi
# 575                                            Se駉rita   Shawn Mendes
# 576                                  How Do You Sleep?      Sam Smith
# 578                             Trampoline (with ZAYN)          SHAED
# 577  South of the Border (feat. Camila Cabello & Ca...     Ed Sheeran
# 580                                        Truth Hurts          Lizzo
# 581         Good as Hell (feat. Ariana Grande) - Remix          Lizzo
# 579                                            Happier     Marshmello
#
#             genre  year  bpm  loudness  track length  popularity
# 572           pop  2019   91        -7           189          99
# 573     dance pop  2019  102        -9           206          97
# 574           pop  2019  110        -6           182          96
# 575  canadian pop  2019  117        -6           191          95
# 576           pop  2019  111        -5           202          93
# 578    electropop  2019  127        -6           184          92
# 577           pop  2019   98        -6           204          92
# 580   escape room  2019  158        -3           173          90
# 581   escape room  2019   96        -3           159          90
# 579       brostep  2019  100        -3           214          90

# %%
print(df['bpm'].describe())
# Out:
# count    603.000000
# mean     118.545605
# std       24.795358
# min        0.000000
# 25%      100.000000
# 50%      120.000000
# 75%      129.000000
# max      206.000000
# Name: bpm, dtype: float64

# %%
print(df['loudness'].describe())
# Out:
# count    603.000000
# mean      -5.578773
# std        2.798020
# min      -60.000000
# 25%       -6.000000
# 50%       -5.000000
# 75%       -4.000000
# max       -2.000000
# Name: loudness, dtype: float64

# %%
print(df['track length'].describe())
# Out:
# count    603.000000
# mean     224.674959
# std       34.130059
# min      134.000000
# 25%      202.000000
# 50%      221.000000
# 75%      239.500000
# max      424.000000
# Name: track length, dtype: float64

# %%
print(df['popularity'].describe())
# Out:
# count    603.000000
# mean      66.520730
# std       14.517746
# min        0.000000
# 25%       60.000000
# 50%       69.000000
# 75%       76.000000
# max       99.000000
# Name: popularity, dtype: float64

# %%
from matplotlib.pyplot import figure

figure(figsize=(15, 10), dpi=80)

ax = sbn.regplot(x = df['bpm'] , y = df['popularity'])

ax.set_xlabel("BPM")
ax.set_ylabel("Popularity")
ax.set_title("BPM vs Popularity") 
df.corr()
# Out:
#                   year       bpm  loudness  track length  popularity
# year          1.000000 -0.104247 -0.126471     -0.215344    0.241261
# bpm          -0.104247  1.000000  0.183870     -0.029359    0.018983
# loudness     -0.126471  0.183870  1.000000     -0.104723    0.156897
# track length -0.215344 -0.029359 -0.104723      1.000000   -0.104363
# popularity    0.241261  0.018983  0.156897     -0.104363    1.000000

# %%
figure(figsize=(15, 10), dpi=80)

ax = sbn.regplot(x = df['track length'] , y = df['popularity'])

ax.set_xlabel("Track Length")
ax.set_ylabel("Popularity")
ax.set_title("Track Length vs Popularity") 
df.corr()
# Out:
#                   year       bpm  loudness  track length  popularity
# year          1.000000 -0.104247 -0.126471     -0.215344    0.241261
# bpm          -0.104247  1.000000  0.183870     -0.029359    0.018983
# loudness     -0.126471  0.183870  1.000000     -0.104723    0.156897
# track length -0.215344 -0.029359 -0.104723      1.000000   -0.104363
# popularity    0.241261  0.018983  0.156897     -0.104363    1.000000

# %%
figure(figsize=(15, 10), dpi=80)

ax = sbn.regplot(x = df['loudness'] , y = df['popularity'])

ax.set_xlabel("Loudness(Decibles)")
ax.set_ylabel("Popularity")
ax.set_title("Loudness vs Popularity") 
df.corr()
# Out:
#                   year       bpm  loudness  track length  popularity
# year          1.000000 -0.104247 -0.126471     -0.215344    0.241261
# bpm          -0.104247  1.000000  0.183870     -0.029359    0.018983
# loudness     -0.126471  0.183870  1.000000     -0.104723    0.156897
# track length -0.215344 -0.029359 -0.104723      1.000000   -0.104363
# popularity    0.241261  0.018983  0.156897     -0.104363    1.000000

# %%
figure(figsize=(15, 10), dpi=80)

ax = sbn.regplot(x = df['year'] , y = df['popularity'])

ax.set_xlabel("year")
ax.set_ylabel("Popularity")
ax.set_title("year vs Popularity") 
df.corr()
# Out:
#                   year       bpm  loudness  track length  popularity
# year          1.000000 -0.131133 -0.204761     -0.187417    0.247182
# bpm          -0.131133  1.000000  0.061171     -0.014068   -0.028517
# loudness     -0.204761  0.061171  1.000000     -0.138607   -0.002970
# track length -0.187417 -0.014068 -0.138607      1.000000   -0.113123
# popularity    0.247182 -0.028517 -0.002970     -0.113123    1.000000

# %%
figure(figsize=(15, 10), dpi=80)

sbn.barplot(x=df["year"], y=df["popularity"])
# Out:
# <AxesSubplot:xlabel='year', ylabel='popularity'>

# %%
figure(figsize=(15, 10), dpi=80)

sbn.barplot(x=df["year"], y=df["bpm"])
# Out:
# <AxesSubplot:xlabel='year', ylabel='bpm'>

# %%
figure(figsize=(15, 10), dpi=80)

sbn.barplot(x=df["year"], y=df["track length"])
# Out:
# <AxesSubplot:xlabel='year', ylabel='track length'>

# %%
figure(figsize=(15, 10), dpi=80)

sbn.barplot(x=df["year"], y=df["loudness"])
# Out:
# <AxesSubplot:xlabel='year', ylabel='loudness'>
