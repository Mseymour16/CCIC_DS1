# %%
#Unsorted Integer

import time
import random
def exchange_sort(a):
    n = len(a)
    global comp
    comp = 0
    
    #outer loop
    for i in range(0,n-1):
        
        #swap if needed
        for j in range(i+1,n):
            if a[i]>a[j]:
                comp = comp + 1
                a[i], a[j] = a[j], a[i]

a = []
listLen = 0

for i in range(0, listLen):
    z = random.randint(-1000000, 1000000)
    a.append(z)

print(a)
x=time.time()
exchange_sort(a)
y=time.time()
print(" ")
print(a)
print(" ")
print(y-x)
print(comp)
# Out:
# []
#
# []
#
# 0.0
# 0

# %%
#FrontHalf Sort Integer

import time
import random
def exchange_sort(a, n):
    global comp
    comp = 0
    
    #outer loop
    for i in range(0,n-1):
        
        #swap if needed
        for j in range(i+1,n):
            if a[i]>a[j]:
                comp = comp + 1
                a[i], a[j] = a[j], a[i]

a = []
listLen = 0

for i in range(0,listLen//2):
  z = random.randint(-1000000, 0)
  a.append(z)
for i in range(0,listLen//2):
  w = random.randint(0, 1000000)
  a.append(w)

n = len(a)
    
print(a)
x=time.time()
exchange_sort(a, n//2)
y=time.time()
print(" ")
print(a)
print(y-x)
print(comp)
# Out:
# []
#
# []
# 0.0
# 0

# %%
#BackHalf Sort Integer

import time
import random
def exchange_sort(a):
    n = len(a)
    global comp
    comp = 0
    
    #outer loop
    for i in range(n//2, n):
        
        #swap if needed
        for j in range(i+1,n):
            if a[i]>a[j]:
                comp = comp + 1
                a[i], a[j] = a[j], a[i]

a = []
listLen = 0

for i in range(0,listLen//2):
  w = random.randint(-1000000, 0)
  a.append(w)
for i in range(0,listLen//2):
  z = random.randint(0, 1000000)
  a.append(z)

print(a)
x=time.time()
exchange_sort(a)
y=time.time()
print(" ")
print(a)
print(y-x)
print(comp)
# Out:
# []
#
# []
# 0.0
# 0

# %%
#Fully Sorted Integer

import time
import random
 
def exchange_sort(a):
    n = len(a)
    global comp
    comp = 0
    
    #outer loop
    for i in range(0,n-1):
        
        #swap if needed
        for j in range(i+1,n):
            if a[i]>a[j]:
                comp = comp + 1
                a[i], a[j] = a[j], a[i]

    
w=[]
listLen = 0

#make sorted list
for i in range(listLen):
    w.append(random.randint(-1000000,1000000))
w.sort()
print("pre sorted list")
print(w)


#run sorted list through alg.
a = w
#print(" ")
#print("before alg.")
#print(a)

x=time.time()
exchange_sort(a)
y=time.time()

print(" ")
print("after alg")
print(a)

print(" ")
print("time")
print(y-x)
print(comp)
# Out:
# pre sorted list
# []
#
# after alg
# []
#
# time
# 0.0
# 0

# %%
#Unsorted Float

import time
import random
def exchange_sort(a):
    n = len(a)
    global comp
    comp = 0
    
    #outer loop
    for i in range(0,n-1):
        
        #swap if needed
        for j in range(i+1,n):
            if a[i]>a[j]:
                comp = comp + 1
                a[i], a[j] = a[j], a[i]

a = []
listLen = 0

for i in range(0, listLen):
    z = round(random.uniform(-1000000.0, 1000000.0), 2)
    a.append(z)

print(a)
x=time.time()
exchange_sort(a)
y=time.time()
print(" ")
print(a)
print(" ")
print(y-x)
print(comp)
# Out:
# []
#
# []
#
# 0.0
# 0

# %%
#FrontHalf Sort Float

import time
import random
import decimal

def exchange_sort(a, n):
    global comp
    comp = 0
    
    #outer loop
    for i in range(0,n-1):
        
        #swap if needed
        for j in range(i+1,n):
            if a[i]>a[j]:
                comp = comp + 1
                a[i], a[j] = a[j], a[i]

a=[]
listLen = 0

for i in range(0,listLen//2):
    z = round(random.uniform(-100000.0,0.0),2)
    a.append(z)
for i in range(0,listLen//2):
    w = round(random.uniform(0.0,1000000.0),2)
    a.append(w)
n = len(a)
    
print(a)
x=time.time()
exchange_sort(a, n//2)
y=time.time()
print(" ")
print(a)
print(y-x)
print(comp)
# Out:
# []
#
# []
# 0.0
# 0

# %%
#BackHalf Sort Float

import time
import random
import decimal

def exchange_sort(a):
    global comp
    comp = 0
    
    #outer loop
    for i in range(n//2,n):
        
        #swap if needed
        for j in range(i+1,n):
            if a[i]>a[j]:
                comp = comp + 1
                a[i], a[j] = a[j], a[i]

a=[]
listLen = 0

for i in range(0,listLen//2):
    w = round(random.uniform(-100000.0,0.0),2)
    a.append(w)
for i in range(0,listLen//2):
    z = round(random.uniform(0.0,1000000.0),2)
    a.append(z)
n = len(a)
    
print(a)
x=time.time()
exchange_sort(a)
y=time.time()
print(" ")
print(a)
print(y-x)
print(comp)
# Out:
# []
#
# []
# 0.0
# 0

# %%
#Fully Sorted Float

import time
import random
 
def exchange_sort(a):
    n = len(a)
    global comp
    comp = 0
    
    #outer loop
    for i in range(0,n-1):
        
        #swap if needed
        for j in range(i+1,n):
            if a[i]>a[j]:
                comp = comp + 1
                a[i], a[j] = a[j], a[i]

    
w=[]
listLen = 0

#make sorted list
for i in range(listLen):
    w.append(round(random.uniform(-1000000.0, 1000000.0), 2))
w.sort()
print("pre sorted list")
print(w)


#run sorted list through alg.
a = w
#print(" ")
#print("before alg.")
#print(a)

x=time.time()
exchange_sort(a)
y=time.time()

print(" ")
print("after alg")
print(a)

print(" ")
print("time")
print(y-x)
print(comp)
# Out:
# pre sorted list
# []
#
# after alg
# []
#
# time
# 0.0

# %%
#Memory Usage

import tracemalloc
import random

temp = random.sample(range(-1000000, 1000000), 2 ** 1)
tracemalloc.start()
x1, y1 = tracemalloc.get_traced_memory() # (current, peak)
temp.sort()
x2, y2 = tracemalloc.get_traced_memory()
tracemalloc.stop()
print(y2 - y1)
# Out:
# 740

# %%
#Unsorted Integer Memory

import tracemalloc
import random
def exchange_sort(a):
    n = len(a)
    
    #outer loop
    for i in range(0,n-1):
        
        #swap if needed
        for j in range(i+1,n):
            if a[i]>a[j]:
                a[i], a[j] = a[j], a[i]

a = []
listLen = 0

for i in range(0, listLen):
    z = random.randint(-1000000, 1000000)
    a.append(z)

print(a)
tracemalloc.start()
x1, y1 = tracemalloc.get_traced_memory()
exchange_sort(a)
x2, y2 = tracemalloc.get_traced_memory()
tracemalloc.stop()
print(" ")
print(a)
print(" ")
print(y2 - y1)
# Out:
# []
#
# []
#
# 1205

# %%
#FrontHalf Sort Integer Memory

import tracemalloc
import random
def exchange_sort(a, n):
    
    #outer loop
    for i in range(0,n-1):
        
        #swap if needed
        for j in range(i+1,n):
            if a[i]>a[j]:
                a[i], a[j] = a[j], a[i]

a = []
listLen = 0

for i in range(0,listLen//2):
  z = random.randint(-1000000, 0)
  a.append(z)
for i in range(0,listLen//2):
  w = random.randint(0, 1000000)
  a.append(w)

n = len(a)

print(a)
tracemalloc.start()
x1, y1 = tracemalloc.get_traced_memory()
exchange_sort(a, n//2)
x2, y2 = tracemalloc.get_traced_memory()
tracemalloc.stop()
print(" ")
print(a)
print(" ")
print(y2 - y1)
# Out:
# []
#
# []
#
# 1227

# %%
#BackHalf Sort Integer Memory

import tracemalloc
import random
def exchange_sort(a):
    n = len(a)
    
    #outer loop
    for i in range(n//2, n):
        
        #swap if needed
        for j in range(i+1,n):
            if a[i]>a[j]:
                a[i], a[j] = a[j], a[i]

a = []
listLen = 0

for i in range(0,listLen//2):
  w = random.randint(-1000000, 0)
  a.append(w)
for i in range(0,listLen//2):
  z = random.randint(0, 1000000)
  a.append(z)

print(a)
tracemalloc.start()
x1, y1 = tracemalloc.get_traced_memory()
exchange_sort(a)
x2, y2 = tracemalloc.get_traced_memory()
tracemalloc.stop()
print(" ")
print(a)
print(" ")
print(y2 - y1)
# Out:
# []
#
# []
#
# 1205

# %%
#Fully Sorted Integer Memory

import tracemalloc
import random
 
def exchange_sort(a):
    n = len(a)
    
    #outer loop
    for i in range(0,n-1):
        
        #swap if needed
        for j in range(i+1,n):
            if a[i]>a[j]:
                a[i], a[j] = a[j], a[i]

    
w=[]
listLen = 0

#make sorted list
for i in range(listLen):
    w.append(random.randint(-1000000,1000000))
w.sort()
print("pre sorted list")
print(w)


#run sorted list through alg.
a = w
#print(" ")
#print("before alg.")
#print(a)

tracemalloc.start()
x1, y1 = tracemalloc.get_traced_memory()
exchange_sort(a)
x2, y2 = tracemalloc.get_traced_memory()
tracemalloc.stop()

print(" ")
print("after alg")
print(a)

print(" ")
print("memory")
print(y2 - y1)
# Out:
# pre sorted list
# []
#
# after alg
# []
#
# memory
# 1205

# %%
#Unsorted Float Memory

import tracemalloc
import random
def exchange_sort(a):
    n = len(a)
    
    #outer loop
    for i in range(0,n-1):
        
        #swap if needed
        for j in range(i+1,n):
            if a[i]>a[j]:
                a[i], a[j] = a[j], a[i]

a = []
listLen = 0

for i in range(0, listLen):
    z = round(random.uniform(-1000000.0, 1000000.0), 2)
    a.append(z)

print(a)
tracemalloc.start()
x1, y1 = tracemalloc.get_traced_memory()
exchange_sort(a)
x2, y2 = tracemalloc.get_traced_memory()
tracemalloc.stop()
print(" ")
print(a)
print(" ")
print(y2 - y1)
# Out:
# []
#
# []
#
# 1205

# %%
#FrontHalf Sort Float Memory

import tracemalloc
import random
import decimal

def exchange_sort(a, n):
    
    #outer loop
    for i in range(0,n-1):
        
        #swap if needed
        for j in range(i+1,n):
            if a[i]>a[j]:
                a[i], a[j] = a[j], a[i]

a=[]
listLen = 0      

for i in range(0,listLen//2):
    z = round(random.uniform(-100000.0,0.0),2)
    a.append(z)
for i in range(0,listLen//2):
    w = round(random.uniform(0.0,1000000.0),2)
    a.append(w)
n = len(a)
    
print(a)
tracemalloc.start()
x1, y1 = tracemalloc.get_traced_memory()
exchange_sort(a, n//2)
x2, y2 = tracemalloc.get_traced_memory()
tracemalloc.stop()
print(" ")
print(a)
print(" ")
print(y2 - y1)
# Out:
# []
#
# []
#
# 1227

# %%
#BackHalf Sort Float Memory

import tracemalloc
import random
import decimal

def exchange_sort(a):
    
    #outer loop
    for i in range(n//2,n):
        
        #swap if needed
        for j in range(i+1,n):
            if a[i]>a[j]:
                a[i], a[j] = a[j], a[i]

a=[]
listLen = 0    

for i in range(0,listLen//2):
    w = round(random.uniform(-100000.0,0.0),2)
    a.append(w)
for i in range(0,listLen//2):
    z = round(random.uniform(0.0,1000000.0),2)
    a.append(z)
n = len(a)
    
print(a)
tracemalloc.start()
x1, y1 = tracemalloc.get_traced_memory()
exchange_sort(a)
x2, y2 = tracemalloc.get_traced_memory()
tracemalloc.stop()
print(" ")
print(a)
print(" ")
print(y2 - y1)
# Out:
# []
#
# []
#
# 1197

# %%
#Fully Sorted Float Memory

import tracemalloc
import random
 
def exchange_sort(a):
    n = len(a)
    
    #outer loop
    for i in range(0,n-1):
        
        #swap if needed
        for j in range(i+1,n):
            if a[i]>a[j]:
                a[i], a[j] = a[j], a[i]

    
w=[]
listLen = 0

#make sorted list
for i in range(listLen):
    w.append(round(random.uniform(-1000000.0, 1000000.0), 2))
w.sort()
print("pre sorted list")
print(w)


#run sorted list through alg.
a = w
#print(" ")
#print("before alg.")
#print(a)

tracemalloc.start()
x1, y1 = tracemalloc.get_traced_memory()
exchange_sort(a)
x2, y2 = tracemalloc.get_traced_memory()
tracemalloc.stop()

print(" ")
print("after alg")
print(a)

print(" ")
print("memory")
print(y2 - y1)
# Out:
# pre sorted list
# []
#
# after alg
# []
#
# memory
# 1205

# %%
one = 0
comp = 0
for i in one:
    if one < 3:
        comp = comp + 1
        
print(comp)
# Out:
# 1
